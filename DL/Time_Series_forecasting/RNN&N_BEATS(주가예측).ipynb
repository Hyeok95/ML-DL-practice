# %% [markdown]
# # 주식 시장 예측해보기
#
# resource: https://www.kaggle.com/faressayah/stock-market-analysis-prediction-using-lstm

# %% [markdown]
# #### 이번 실습에서는 주가 데이터를 예측하는 일을 해볼 것 입니다.
# #### RNN, LSTM, GRU, N-BEATS 모델을 통해 미래의 주가를 예측해봅시다.

# %% [markdown]
# # 1. Pandas 를 이용한 데이터 전처리 및 matplotlib, seaborn 을 이용한 데이터 시각화

# %%
from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !pip install yfinance
import yfinance as yf
from datetime import datetime

# Apple, Google, Microsoft, Amazon 데이터를 수집해봅시다
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

end = datetime.now()
start = datetime(end.year - 10, end.month, end.day) # 오늘부터 이전 10년간의 데이터를 모아봅시다.

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end) # yfinance 라이브러리는 주식 데이터를 자동으로 다운로드 받게 해줍니다.
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.68-py2.py3-none-any.whl (26 kB)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.4 MB/s
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 8.7 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.7.1 requests-2.27.1 yfinance-0.1.68
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Let's go ahead and play aorund with the AAPL DataFrame to get a feel for the data

# %%
company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)

# %% [markdown]
# 데이터는 6가지의 feature로 구성되어 있습니다.
# 1. Open(시작가)
# 2. High(최고가)
# 3. Low(최저가)
# 4. Close(종가)
# 5. Adj Close(조정된 종가)
# 6. Volume(거래량)

# %%
df
# Out:
#                    Open         High  ...     Volume  company_name
# Date                                  ...
# 2012-01-12    15.081429    15.103571  ...  212587200         APPLE
# 2012-01-13    14.989286    15.016071  ...  226021600         APPLE
# 2012-01-17    15.150000    15.213929  ...  242897200         APPLE
# 2012-01-18    15.248571    15.338214  ...  276791200         APPLE
# 2012-01-19    15.362500    15.406071  ...  261738400         APPLE
# ...                 ...          ...  ...        ...           ...
# 2022-01-05  3337.659912  3342.530029  ...    3215100        AMAZON
# 2022-01-06  3269.010010  3296.000000  ...    2597900        AMAZON
# 2022-01-07  3276.780029  3304.870117  ...    2329300        AMAZON
# 2022-01-10  3211.709961  3233.229980  ...    4389900        AMAZON
# 2022-01-11  3230.000000  3327.000000  ...    3131500        AMAZON
#
# [10068 rows x 7 columns]

# %%
# Summary Stats
AAPL.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  2517.000000  2517.000000  ...  2517.000000  2.517000e+03
# mean     49.462477    49.981625  ...    47.737024  2.145457e+08
# std      39.220763    39.693572  ...    39.903133  1.759101e+08
# min      13.856071    14.271429  ...    12.134604  4.100000e+07
# 25%      23.732500    23.934999  ...    21.353045  1.027696e+08
# 50%      32.517502    32.735001  ...    29.691391  1.506940e+08
# 75%      54.447498    55.112499  ...    52.694386  2.644760e+08
# max     182.630005   182.940002  ...   182.009995  1.506120e+09
#
# [8 rows x 6 columns]

# %%
# General info
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2012-01-12 to 2022-01-11
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2517 non-null   float64
#  1   High          2517 non-null   float64
#  2   Low           2517 non-null   float64
#  3   Close         2517 non-null   float64
#  4   Adj Close     2517 non-null   float64
#  5   Volume        2517 non-null   int64
#  6   company_name  2517 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 157.3+ KB

# %%
# 과거의 종가 데이터를 한번 확인해봅시다.
plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# 과거의 거래량을 확인해봅시다.
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
df.groupby("company_name").hist(figsize=(12, 12))
# Out:
# company_name
# AMAZON       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# APPLE        [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# GOOGLE       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# MICROSOFT    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# dtype: object

# %% [markdown]
# # 2. Moving average를 통해 데이터의 변화 양상을 확인해봅시다.

# %%
ma_day = [10, 20, 50] # 10일치, 20일치, 50일치의 moving average를 통해 변화양상을 확인해봅시다.

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
print(GOOG.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'company_name',
#        'MA for 10 days', 'MA for 20 days', 'MA for 50 days'],
#       dtype='object')

# %% [markdown]
# - moving average에 사용되는 window의 크기가 클수록 더 긴 기간의 trend를 확인할 수 있고, window의 크기가 작을수록 짧은 구간의 trend 변화를 확인할 수 있습니다.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

plot_columns = ['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']

AAPL[plot_columns].iloc[-300:].plot(ax=axes[0,0])   #.iloc[-500:].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[plot_columns].iloc[-300:].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[plot_columns].iloc[-300:].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[plot_columns].iloc[-300:].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# # 3. 수익률을 분석해봅시다.
# - Pandas dataframe 은 pct_change 라는 수익률 분석 함수를 제공합니다. 이 함수는 아래의 값을 계산합니다.
#     - (현재 값 - 직전 값)/직전 값
#     - 종가에 적용하면 전날 종가대비 당일의 종가가 얼마나 상승했는지를 비율로 나타내게 됩니다.

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# - Histogram 을 이용해서도 분석해봅시다. (Seaborn 라이브러리 이용)

# %%
plt.figure(figsize=(12, 7))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    sns.distplot(company['Daily Return'].dropna(), bins=100, color='purple') # nan value는 seaborn 에서 읽을 수 없으므로 dropna 를 통해 처리하였습니다.
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# pandas dataframe 에서 제공하는 histogram 함수를 사용해도 됩니다.
AAPL['Daily Return'].hist()

# %% [markdown]
# # 4. 서로 다른 주식의 종가들 간의 관계성을 분석해봅시다.

# %% [markdown]
# Now that we have all the closing prices, let's go ahead and get the daily return for all the stocks, like we did for the Apple stock.

# %%
closing_df = pd.DataFrame([AAPL['Adj Close'], GOOG['Adj Close'], MSFT['Adj Close'], AMZN['Adj Close']]).T
closing_df.columns = ['AAPL','GOOG','MSFT','AMZN']

# %%
# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.tail()
# Out:
#                 AAPL      GOOG      MSFT      AMZN
# Date
# 2022-01-05 -0.026600 -0.046830 -0.038388 -0.018893
# 2022-01-06 -0.016693 -0.000745 -0.007902 -0.006711
# 2022-01-07  0.000988 -0.003973  0.000510 -0.004288
# 2022-01-10  0.000116  0.011456  0.000732 -0.006570
# 2022-01-11  0.016784  0.010417  0.002259  0.024002

# %% [markdown]
# - seaborn 라이브러리의 jointplot을 통해 관계성을 분석해봅시다.

# %%
# 자기 자신과의 비교를 먼저 진행해봅시다. 자기 자신과 비교하면 correlation이 아주 강하게 나타나는 것을 볼 수 있습니다. (correlation = 1.0, 정비례)
sns.jointplot('GOOG', 'GOOG', tech_rets, kind='scatter', color='seagreen')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Google 과 Microsoft를 비교해봅시다.
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')

"""
결과를 통해 아래의 질문에 답을 해보세요.
1. correlation이 높은가요? 아니면 낮은가요?
2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?
"""
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# '\n결과를 통해 아래의 질문에 답을 해보세요.\n1. correlation이 높은가요? 아니면 낮은가요?\n2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?\n'

# %% [markdown]
# - Pandas와 seaborn을 혼합하면 이러한 분석을 모든 pair에 대해 아주 쉽게 적용할 수 있습니다.

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %% [markdown]
# - Seaborn 의 pairplot은 pairgrid 함수를 통해 좀 더 다양한 버전으로 적용될 수 있습니다. 이를 통해 다양한 방식으로 데이터를 분석하는 것이 가능합니다.
#     - 여기서는 이를 통해 분석을 진행하기보다는, 사용하는 방법에 대해서만 확인하고 넘어가도록 하겠습니다.
#     - 이 예제에서는 위쪽 삼각형에서는 scatter plot, 아래쪽 삼각형에서는 kernel density estimation plot, 대각에는 histogram을 그려보겠습니다.

# %%
# 우선, 수익률을 통해 분석해봅시다.
return_fig = sns.PairGrid(tech_rets.dropna())

return_fig.map_upper(plt.scatter, color='purple')
return_fig.map_lower(sns.kdeplot, cmap='cool_d') # kde 에서 회색 선은 등고선을 의미합니다
return_fig.map_diag(plt.hist, bins=30)

# %%
# 종가 데이터를 통해 분석해봅시다.
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='purple')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30)

# %% [markdown]
# - pandas 의 corr 함수를 통해 pearson correlation을 간단히 계산할 수도 있습니다.

# %%
sns.heatmap(tech_rets.corr(), annot=True, cmap='viridis')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='viridis')

# %% [markdown]
# # 5. Apple, Google, Microsoft, Amazon의 주식 종가를 예측해봅시다.

# %%
df = closing_df

# %%
df.columns
# Out:
# Index(['AAPL', 'GOOG', 'MSFT', 'AMZN'], dtype='object')

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['AAPL'], label='Apple')
plt.plot(df['GOOG'], label='Google')
plt.plot(df['MSFT'], label='Microsoft')
plt.plot(df['AMZN'], label='Amazon')
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %% [markdown]
# # 5-1. 데이터 전처리

# %%
# data split 
train_data_length = int(len(df) * 0.8)
val_data_length = int(len(df) * 0.1)

train_df = df.iloc[:train_data_length]
val_df = df.iloc[train_data_length:train_data_length+val_data_length]
test_df = df.iloc[train_data_length+val_data_length:]

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2013, 4), (251, 4), (253, 4))

# %% [markdown]
# # 5-2. Dataset class 만들기, Dataloader 만들기

# %%
class StandardScaler():
    def __init__(self):
        self.mean = None
        self.stdev = None
        
    def fit(self, x, dim=None):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        if dim is not None:
            self.mean = x.mean(dim)
            self.stdev = x.std(dim)
        else:
            self.mean = x.mean()
            self.stdev = x.std()
        
    def scale(self, x):# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return (x - self.mean.to(x.device)) / self.stdev.to(x.device)
    
    def unscale(self, x):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return x * self.stdev.to(x.device) + self.mean.to(x.device)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

class TimeseriesDataset(torch.utils.data.Dataset):   
    def __init__(self, data, backcast_length, forecast_length, scaler=None):
        self.data_columns = data.columns
        self.data = data.values
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        
        if scaler is None:
            # train
            self.scaler = StandardScaler()
            self.scaler.fit(self.data, dim=0)
        else:
            self.scaler = scaler
        self.data = self.scaler.scale(self.data)
        

    def __len__(self):
        return len(self.data) - self.backcast_length - self.forecast_length + 1

    def __getitem__(self, idx):
        x_end = idx + self.backcast_length
        y_end = x_end + self.forecast_length

        x = self.data[idx:x_end]
        y = self.data[x_end:y_end]
        
        x = x.float()
        y = y.float()
        
        return x, y 
    
    def unscale(self, x):
        return self.scaler.unscale(x)

# %%
batch_size = 128
num_workers = 2
pin_memory = True

backcast_length = 30
forecast_length = 30

# %%
train_dataset = TimeseriesDataset(train_df, backcast_length, forecast_length, scaler=None)
val_dataset = TimeseriesDataset(val_df, backcast_length, forecast_length, scaler=train_dataset.scaler)
test_dataset = TimeseriesDataset(test_df, backcast_length, forecast_length, scaler=train_dataset.scaler)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, 
                                               num_workers=num_workers, pin_memory=pin_memory)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)

# %% [markdown]
# # 5-3. 모델 정의하기

# %%
class RNNmodel(nn.Module):
    def __init__(self, feature_dim, hidden_dim, LSTM=False, GRU=False, num_layers=4, bidirectional=False, dropout=0.3, batch_first=True, backcast_length=30, forecast_length=30):
        super(RNNmodel, self).__init__()
        self.LSTM = LSTM # LSTM인지 아닌지 여부를 저장해둡니다.
        self.n_direction = 2 if bidirectional else 1
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        
        
        if LSTM:
            rnn = nn.LSTM
        elif GRU:
            rnn = nn.GRU
        else:
            rnn = nn.RNN
            
            
        self.rnn = rnn(input_size = feature_dim, 
                       hidden_size = hidden_dim, 
                       num_layers = num_layers,
                       bias = True,
                       batch_first = batch_first,
                       dropout = dropout,
                       bidirectional = bidirectional)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        self.out = nn.Linear(hidden_dim * self.n_direction, feature_dim)
        
    def forward(self, x):
        # x: (batch, sequence length, feature_dim)
        
        
        # many to many 구조를 구현해봅시다.
        
        if self.LSTM:
            h0 = (torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device),
                  torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device))
        else:
            h0 = torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device)
        
        x, h = self.rnn(x, h0)
        outs = []
        for i in range(self.forecast_length):
            x = self.out(x[:,-1:,:])
            outs.append(x.squeeze(1))
            
            if i == self.forecast_length-1:
                break
                
            x, h = self.rnn(x, h)
            
        outs = torch.stack(outs, dim=1)
        return outs

# %%
feature_dim=4
hidden_dim=64

model = RNNmodel(feature_dim, hidden_dim, LSTM=True, GRU=False)
model = model.cuda()

# %% [markdown]
# # 5-4. 학습 방식 정의하기

# %%
learning_rate = 1e-4
num_epoch = 100

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 5-5. 학습 진행하기

# %%
import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        
        forecast = model(inputs)
    
        forecast = model(inputs)
        loss = criterion(forecast, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:
            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
            inputs = inputs.cuda()
            labels = labels.cuda()

            forecast = model(inputs)
            loss = criterion(forecast, labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)# We can simply call pairplot on our DataFrame for an automatic visual analysis
# Out:
# epoch [0/100] iter [000/016] loss [0.7879] elapsed time [0.00min]
# epoch [0/100] train loss [0.8298] validation loss [3.9184] elapsed time [0.03 min]
#
# epoch [1/100] iter [000/016] loss [0.8114] elapsed time [0.03min]
# epoch [1/100] train loss [0.8272] validation loss [3.9371] elapsed time [0.05 min]
#
# epoch [2/100] iter [000/016] loss [0.8164] elapsed time [0.06min]
# epoch [2/100] train loss [0.8252] validation loss [3.9630] elapsed time [0.08 min]
#
# epoch [3/100] iter [000/016] loss [0.8779] elapsed time [0.08min]
# epoch [3/100] train loss [0.8166] validation loss [4.0089] elapsed time [0.10 min]
#
# epoch [4/100] iter [000/016] loss [0.8472] elapsed time [0.11min]
# epoch [4/100] train loss [0.7954] validation loss [4.1032] elapsed time [0.13 min]
#
# epoch [5/100] iter [000/016] loss [0.7473] elapsed time [0.13min]
# epoch [5/100] train loss [0.7330] validation loss [4.0969] elapsed time [0.15 min]
#
# epoch [6/100] iter [000/016] loss [0.7261] elapsed time [0.16min]
# epoch [6/100] train loss [0.6120] validation loss [3.9736] elapsed time [0.18 min]
#
# epoch [7/100] iter [000/016] loss [0.4691] elapsed time [0.18min]
# epoch [7/100] train loss [0.5220] validation loss [3.9152] elapsed time [0.21 min]
#
# epoch [8/100] iter [000/016] loss [0.4620] elapsed time [0.21min]
# epoch [8/100] train loss [0.5115] validation loss [3.8838] elapsed time [0.23 min]
#
# epoch [9/100] iter [000/016] loss [0.6573] elapsed time [0.23min]
# epoch [9/100] train loss [0.4967] validation loss [3.8519] elapsed time [0.26 min]
#
# epoch [10/100] iter [000/016] loss [0.4738] elapsed time [0.26min]
# epoch [10/100] train loss [0.4766] validation loss [3.8083] elapsed time [0.28 min]
#
# epoch [11/100] iter [000/016] loss [0.4752] elapsed time [0.28min]
# epoch [11/100] train loss [0.4601] validation loss [3.7449] elapsed time [0.31 min]
#
# epoch [12/100] iter [000/016] loss [0.4173] elapsed time [0.31min]
# epoch [12/100] train loss [0.4345] validation loss [3.6484] elapsed time [0.33 min]
#
# epoch [13/100] iter [000/016] loss [0.3728] elapsed time [0.33min]
# epoch [13/100] train loss [0.3945] validation loss [3.5125] elapsed time [0.36 min]
#
# epoch [14/100] iter [000/016] loss [0.3410] elapsed time [0.36min]
# epoch [14/100] train loss [0.3593] validation loss [3.3452] elapsed time [0.38 min]
#
# epoch [15/100] iter [000/016] loss [0.3203] elapsed time [0.39min]
# epoch [15/100] train loss [0.3126] validation loss [3.1524] elapsed time [0.41 min]
#
# epoch [16/100] iter [000/016] loss [0.2618] elapsed time [0.41min]
# epoch [16/100] train loss [0.2726] validation loss [2.9624] elapsed time [0.43 min]
#
# epoch [17/100] iter [000/016] loss [0.2487] elapsed time [0.44min]
# epoch [17/100] train loss [0.2379] validation loss [2.7976] elapsed time [0.46 min]
#
# epoch [18/100] iter [000/016] loss [0.2130] elapsed time [0.46min]
# epoch [18/100] train loss [0.1980] validation loss [2.6350] elapsed time [0.49 min]
#
# epoch [19/100] iter [000/016] loss [0.1746] elapsed time [0.49min]
# epoch [19/100] train loss [0.1742] validation loss [2.4879] elapsed time [0.51 min]
#
# epoch [20/100] iter [000/016] loss [0.1769] elapsed time [0.51min]
# epoch [20/100] train loss [0.1638] validation loss [2.3903] elapsed time [0.54 min]
#
# epoch [21/100] iter [000/016] loss [0.1506] elapsed time [0.54min]
# epoch [21/100] train loss [0.1583] validation loss [2.3183] elapsed time [0.56 min]
#
# epoch [22/100] iter [000/016] loss [0.1499] elapsed time [0.57min]
# epoch [22/100] train loss [0.1532] validation loss [2.2591] elapsed time [0.59 min]
#
# epoch [23/100] iter [000/016] loss [0.1432] elapsed time [0.59min]
# epoch [23/100] train loss [0.1521] validation loss [2.2332] elapsed time [0.61 min]
#
# epoch [24/100] iter [000/016] loss [0.1486] elapsed time [0.62min]
# epoch [24/100] train loss [0.1512] validation loss [2.2124] elapsed time [0.64 min]
#
# epoch [25/100] iter [000/016] loss [0.1538] elapsed time [0.64min]
# epoch [25/100] train loss [0.1493] validation loss [2.1968] elapsed time [0.66 min]
#
# epoch [26/100] iter [000/016] loss [0.1519] elapsed time [0.67min]
# epoch [26/100] train loss [0.1479] validation loss [2.1740] elapsed time [0.69 min]
#
# epoch [27/100] iter [000/016] loss [0.1534] elapsed time [0.69min]
# epoch [27/100] train loss [0.1490] validation loss [2.1671] elapsed time [0.72 min]
#
# epoch [28/100] iter [000/016] loss [0.1608] elapsed time [0.72min]
# epoch [28/100] train loss [0.1485] validation loss [2.1536] elapsed time [0.74 min]
#
# epoch [29/100] iter [000/016] loss [0.1565] elapsed time [0.74min]
# epoch [29/100] train loss [0.1468] validation loss [2.1485] elapsed time [0.77 min]
#
# epoch [30/100] iter [000/016] loss [0.1409] elapsed time [0.77min]
# epoch [30/100] train loss [0.1473] validation loss [2.1424] elapsed time [0.79 min]
#
# epoch [31/100] iter [000/016] loss [0.1499] elapsed time [0.80min]
# epoch [31/100] train loss [0.1499] validation loss [2.1310] elapsed time [0.82 min]
#
# epoch [32/100] iter [000/016] loss [0.1582] elapsed time [0.82min]
# epoch [32/100] train loss [0.1453] validation loss [2.1085] elapsed time [0.84 min]
#
# epoch [33/100] iter [000/016] loss [0.1484] elapsed time [0.85min]
# epoch [33/100] train loss [0.1469] validation loss [2.1035] elapsed time [0.87 min]
#
# epoch [34/100] iter [000/016] loss [0.1435] elapsed time [0.87min]
# epoch [34/100] train loss [0.1453] validation loss [2.1004] elapsed time [0.89 min]
#
# epoch [35/100] iter [000/016] loss [0.1391] elapsed time [0.90min]
# epoch [35/100] train loss [0.1451] validation loss [2.0919] elapsed time [0.92 min]
#
# epoch [36/100] iter [000/016] loss [0.1441] elapsed time [0.92min]
# epoch [36/100] train loss [0.1446] validation loss [2.0821] elapsed time [0.95 min]
#
# epoch [37/100] iter [000/016] loss [0.1419] elapsed time [0.95min]
# epoch [37/100] train loss [0.1438] validation loss [2.0780] elapsed time [0.97 min]
#
# epoch [38/100] iter [000/016] loss [0.1513] elapsed time [0.98min]
# epoch [38/100] train loss [0.1445] validation loss [2.0700] elapsed time [1.00 min]
#
# epoch [39/100] iter [000/016] loss [0.1432] elapsed time [1.00min]
# epoch [39/100] train loss [0.1409] validation loss [2.0690] elapsed time [1.02 min]
#
# epoch [40/100] iter [000/016] loss [0.1322] elapsed time [1.03min]
# epoch [40/100] train loss [0.1431] validation loss [2.0622] elapsed time [1.05 min]
#
# epoch [41/100] iter [000/016] loss [0.1367] elapsed time [1.05min]
# epoch [41/100] train loss [0.1415] validation loss [2.0659] elapsed time [1.07 min]
#
# epoch [42/100] iter [000/016] loss [0.1582] elapsed time [1.08min]
# epoch [42/100] train loss [0.1416] validation loss [2.0738] elapsed time [1.10 min]
#
# epoch [43/100] iter [000/016] loss [0.1472] elapsed time [1.10min]
# epoch [43/100] train loss [0.1407] validation loss [2.0608] elapsed time [1.13 min]
#
# epoch [44/100] iter [000/016] loss [0.1410] elapsed time [1.13min]
# epoch [44/100] train loss [0.1401] validation loss [2.0546] elapsed time [1.15 min]
#
# epoch [45/100] iter [000/016] loss [0.1337] elapsed time [1.16min]
# epoch [45/100] train loss [0.1414] validation loss [2.0588] elapsed time [1.18 min]
#
# epoch [46/100] iter [000/016] loss [0.1441] elapsed time [1.18min]
# epoch [46/100] train loss [0.1398] validation loss [2.0616] elapsed time [1.20 min]
#
# epoch [47/100] iter [000/016] loss [0.1483] elapsed time [1.21min]
# epoch [47/100] train loss [0.1382] validation loss [2.0616] elapsed time [1.23 min]
#
# epoch [48/100] iter [000/016] loss [0.1441] elapsed time [1.23min]
# epoch [48/100] train loss [0.1390] validation loss [2.0568] elapsed time [1.26 min]
#
# epoch [49/100] iter [000/016] loss [0.1293] elapsed time [1.26min]
# epoch [49/100] train loss [0.1388] validation loss [2.0615] elapsed time [1.28 min]
#
# epoch [50/100] iter [000/016] loss [0.1318] elapsed time [1.28min]
# epoch [50/100] train loss [0.1388] validation loss [2.0686] elapsed time [1.31 min]
#
# epoch [51/100] iter [000/016] loss [0.1447] elapsed time [1.31min]
# epoch [51/100] train loss [0.1374] validation loss [2.0610] elapsed time [1.33 min]
#
# epoch [52/100] iter [000/016] loss [0.1324] elapsed time [1.34min]
# epoch [52/100] train loss [0.1385] validation loss [2.0670] elapsed time [1.36 min]
#
# epoch [53/100] iter [000/016] loss [0.1620] elapsed time [1.36min]
# epoch [53/100] train loss [0.1378] validation loss [2.0705] elapsed time [1.38 min]
#
# epoch [54/100] iter [000/016] loss [0.1466] elapsed time [1.39min]
# epoch [54/100] train loss [0.1380] validation loss [2.0728] elapsed time [1.41 min]
#
# epoch [55/100] iter [000/016] loss [0.1450] elapsed time [1.41min]
# epoch [55/100] train loss [0.1366] validation loss [2.0719] elapsed time [1.43 min]
#
# epoch [56/100] iter [000/016] loss [0.1402] elapsed time [1.44min]
# epoch [56/100] train loss [0.1374] validation loss [2.0772] elapsed time [1.46 min]
#
# epoch [57/100] iter [000/016] loss [0.1315] elapsed time [1.46min]
# epoch [57/100] train loss [0.1362] validation loss [2.0724] elapsed time [1.49 min]
#
# epoch [58/100] iter [000/016] loss [0.1328] elapsed time [1.49min]
# epoch [58/100] train loss [0.1358] validation loss [2.0850] elapsed time [1.51 min]
#
# epoch [59/100] iter [000/016] loss [0.1350] elapsed time [1.52min]
# epoch [59/100] train loss [0.1354] validation loss [2.0879] elapsed time [1.54 min]
#
# epoch [60/100] iter [000/016] loss [0.1318] elapsed time [1.54min]
# epoch [60/100] train loss [0.1347] validation loss [2.0881] elapsed time [1.56 min]
#
# epoch [61/100] iter [000/016] loss [0.1348] elapsed time [1.57min]
# epoch [61/100] train loss [0.1361] validation loss [2.0851] elapsed time [1.59 min]
#
# epoch [62/100] iter [000/016] loss [0.1317] elapsed time [1.59min]
# epoch [62/100] train loss [0.1341] validation loss [2.0863] elapsed time [1.61 min]
#
# epoch [63/100] iter [000/016] loss [0.1253] elapsed time [1.62min]
# epoch [63/100] train loss [0.1331] validation loss [2.0860] elapsed time [1.64 min]
#
# epoch [64/100] iter [000/016] loss [0.1257] elapsed time [1.64min]
# epoch [64/100] train loss [0.1322] validation loss [2.0838] elapsed time [1.67 min]
#
# epoch [65/100] iter [000/016] loss [0.1277] elapsed time [1.67min]
# epoch [65/100] train loss [0.1327] validation loss [2.0819] elapsed time [1.69 min]
#
# epoch [66/100] iter [000/016] loss [0.1275] elapsed time [1.70min]
# epoch [66/100] train loss [0.1325] validation loss [2.0829] elapsed time [1.72 min]
#
# epoch [67/100] iter [000/016] loss [0.1252] elapsed time [1.72min]
# epoch [67/100] train loss [0.1326] validation loss [2.0853] elapsed time [1.74 min]
#
# epoch [68/100] iter [000/016] loss [0.1389] elapsed time [1.75min]
# epoch [68/100] train loss [0.1318] validation loss [2.0815] elapsed time [1.77 min]
#
# epoch [69/100] iter [000/016] loss [0.1367] elapsed time [1.77min]
# epoch [69/100] train loss [0.1313] validation loss [2.0856] elapsed time [1.79 min]
#
# epoch [70/100] iter [000/016] loss [0.1302] elapsed time [1.80min]
# epoch [70/100] train loss [0.1300] validation loss [2.0856] elapsed time [1.82 min]
#
# epoch [71/100] iter [000/016] loss [0.1235] elapsed time [1.82min]
# epoch [71/100] train loss [0.1302] validation loss [2.0882] elapsed time [1.84 min]
#
# epoch [72/100] iter [000/016] loss [0.1305] elapsed time [1.85min]
# epoch [72/100] train loss [0.1280] validation loss [2.0869] elapsed time [1.87 min]
#
# epoch [73/100] iter [000/016] loss [0.1258] elapsed time [1.87min]
# epoch [73/100] train loss [0.1296] validation loss [2.0840] elapsed time [1.90 min]
#
# epoch [74/100] iter [000/016] loss [0.1235] elapsed time [1.90min]
# epoch [74/100] train loss [0.1280] validation loss [2.0805] elapsed time [1.92 min]
#
# epoch [75/100] iter [000/016] loss [0.1303] elapsed time [1.93min]
# epoch [75/100] train loss [0.1265] validation loss [2.0759] elapsed time [1.95 min]
#
# epoch [76/100] iter [000/016] loss [0.1211] elapsed time [1.95min]
# epoch [76/100] train loss [0.1270] validation loss [2.0816] elapsed time [1.97 min]
#
# epoch [77/100] iter [000/016] loss [0.1155] elapsed time [1.98min]
# epoch [77/100] train loss [0.1264] validation loss [2.0745] elapsed time [2.00 min]
#
# epoch [78/100] iter [000/016] loss [0.1177] elapsed time [2.00min]
# epoch [78/100] train loss [0.1262] validation loss [2.0785] elapsed time [2.03 min]
#
# epoch [79/100] iter [000/016] loss [0.1170] elapsed time [2.03min]
# epoch [79/100] train loss [0.1261] validation loss [2.0746] elapsed time [2.05 min]
#
# epoch [80/100] iter [000/016] loss [0.1284] elapsed time [2.05min]
# epoch [80/100] train loss [0.1242] validation loss [2.0708] elapsed time [2.08 min]
#
# epoch [81/100] iter [000/016] loss [0.1272] elapsed time [2.08min]
# epoch [81/100] train loss [0.1240] validation loss [2.0707] elapsed time [2.10 min]
#
# epoch [82/100] iter [000/016] loss [0.1242] elapsed time [2.11min]
# epoch [82/100] train loss [0.1229] validation loss [2.0658] elapsed time [2.13 min]
#
# epoch [83/100] iter [000/016] loss [0.1248] elapsed time [2.13min]
# epoch [83/100] train loss [0.1241] validation loss [2.0682] elapsed time [2.15 min]
#
# epoch [84/100] iter [000/016] loss [0.1255] elapsed time [2.16min]
# epoch [84/100] train loss [0.1234] validation loss [2.0657] elapsed time [2.18 min]
#
# epoch [85/100] iter [000/016] loss [0.1277] elapsed time [2.18min]
# epoch [85/100] train loss [0.1225] validation loss [2.0622] elapsed time [2.21 min]
#
# epoch [86/100] iter [000/016] loss [0.1253] elapsed time [2.21min]
# epoch [86/100] train loss [0.1227] validation loss [2.0616] elapsed time [2.23 min]
#
# epoch [87/100] iter [000/016] loss [0.1201] elapsed time [2.24min]
# epoch [87/100] train loss [0.1214] validation loss [2.0522] elapsed time [2.26 min]
#
# epoch [88/100] iter [000/016] loss [0.1274] elapsed time [2.26min]
# epoch [88/100] train loss [0.1198] validation loss [2.0517] elapsed time [2.28 min]
#
# epoch [89/100] iter [000/016] loss [0.1223] elapsed time [2.29min]
# epoch [89/100] train loss [0.1197] validation loss [2.0462] elapsed time [2.31 min]
#
# epoch [90/100] iter [000/016] loss [0.1170] elapsed time [2.31min]
# epoch [90/100] train loss [0.1180] validation loss [2.0474] elapsed time [2.34 min]
#
# epoch [91/100] iter [000/016] loss [0.1308] elapsed time [2.34min]
# epoch [91/100] train loss [0.1173] validation loss [2.0426] elapsed time [2.36 min]
#
# epoch [92/100] iter [000/016] loss [0.1209] elapsed time [2.36min]
# epoch [92/100] train loss [0.1179] validation loss [2.0416] elapsed time [2.39 min]
#
# epoch [93/100] iter [000/016] loss [0.1170] elapsed time [2.39min]
# epoch [93/100] train loss [0.1155] validation loss [2.0413] elapsed time [2.41 min]
#
# epoch [94/100] iter [000/016] loss [0.1245] elapsed time [2.42min]
# epoch [94/100] train loss [0.1172] validation loss [2.0371] elapsed time [2.44 min]
#
# epoch [95/100] iter [000/016] loss [0.1105] elapsed time [2.44min]
# epoch [95/100] train loss [0.1143] validation loss [2.0323] elapsed time [2.46 min]
#
# epoch [96/100] iter [000/016] loss [0.1191] elapsed time [2.47min]
# epoch [96/100] train loss [0.1149] validation loss [2.0248] elapsed time [2.49 min]
#
# epoch [97/100] iter [000/016] loss [0.1096] elapsed time [2.49min]
# epoch [97/100] train loss [0.1132] validation loss [2.0210] elapsed time [2.52 min]
#
# epoch [98/100] iter [000/016] loss [0.1125] elapsed time [2.52min]
# epoch [98/100] train loss [0.1120] validation loss [2.0177] elapsed time [2.54 min]
#
# epoch [99/100] iter [000/016] loss [0.1146] elapsed time [2.54min]
# epoch [99/100] train loss [0.1096] validation loss [2.0100] elapsed time [2.57 min]

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping 
plt.legend()
plt.show()

# %%
best_epoch
# Out:
# 99

# %%
model.load_state_dict(best_model_state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # validation data 에 대한 실제 값과 예측 값을 확인해봅시다.

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
model.eval()
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)

# %%
predictions.shape
# Out:
# torch.Size([192, 30, 4])

# %%
def plot_prediction_after_N_days(real,pred,N=5):
    
    pred = pred[:,N,:]
    real = real.iloc[N:]
    real = real.iloc[:len(pred)]
    
    cmap=['red','orange','skyblue','green']
    plt.figure(figsize=(16,5))
    for i, col in enumerate(real.columns):
        plt.plot(real[col], label=col+' Real', c=cmap[i], linestyle='--')
    
    pred_df = pd.DataFrame(pred.data.cpu().numpy())
    pred_df.index = real.index
    pred_df.columns = real.columns
    for i, col in enumerate(real.columns):
        plt.plot(pred_df[col], label=col+' Pred', c=cmap[i])
    plt.legend()
    plt.show()

# %%
validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %% [markdown]
# # Test 데이터에도 적용해봅시다.

# %%
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)

# %%
test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=1)

# %% [markdown]
# # 6. N-BEATS 모델을 사용해봅시다.

# %%
class NBeatsNet(nn.Module):
    def __init__(self,
                 forecast_length=24,
                 backcast_length=96,
                 theta_dim=(2, 8, 3),
                 n_trend=3,
                 n_seasonality=3,
                 n_residual=3,
                 hidden_dim=512,
                 feature_dim=4):
        super(NBeatsNet, self).__init__()        
            
        self.trend_stack = []
        self.seasonality_stack = []
        self.residual_stack = [] #bs =[] 이건했는데 fs=[] 이거 안해줌
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        for i in range(n_trend):
            self.trend_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[0], mode='trend', feature_dim=feature_dim))    

        for i in range(n_seasonality):
            self.seasonality_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[1], mode='seasonality', feature_dim=feature_dim))
        
        for i in range(n_residual):
            self.residual_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[2], mode='residual', feature_dim=feature_dim))
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        self.trend_stack = nn.ModuleList(self.trend_stack)
        self.seasonality_stack = nn.ModuleList(self.seasonality_stack)
        self.residual_stack = nn.ModuleList(self.residual_stack)

    def forward(self, backcast):# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        backcast_stack = []
        forecast_stack = []

        for layer in self.trend_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        for layer in self.seasonality_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b


        for layer in self.residual_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        backcast = torch.stack(backcast_stack, 0)
        forecast = torch.stack(forecast_stack, 0)
        return backcast, forecast


# ours
class Block(nn.Module):
    def __init__(self, backcast_length, forecast_length, hidden_dim, theta_dim, mode, feature_dim):
        super(Block, self).__init__()
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.theta_dim = theta_dim
        self.mode = mode

        self.MLP = nn.Sequential(
                nn.Linear(backcast_length * feature_dim, hidden_dim), 
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU()
            ) # univariate??multivariate??

        if mode == 'residual':
            # residual  
            self.theta_b = nn.Linear(hidden_dim, theta_dim * feature_dim)             
            self.theta_f = nn.Linear(hidden_dim, theta_dim * feature_dim)
            self.linear_b = nn.Linear(theta_dim, backcast_length)
            self.linear_f = nn.Linear(theta_dim, forecast_length)
        else:
            # trend, seasonality# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            self.theta = nn.Linear(hidden_dim, theta_dim*feature_dim)


    def forward(self, x):
        shape = x.shape
        # x: (batch size, backcast length, feature_dim)
        t_b = ((torch.arange(start=0, end=self.backcast_length, device=x.device, dtype=torch.float) - self.backcast_length) / 24 ) # (backcast_len,)
        t_f = ((torch.arange(start=0, end=self.forecast_length, device=x.device, dtype=torch.float)) / 24 ) # (forecast_len,)

        # x -> h
        x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        # h -> theta -> backcast, forecast
        if self.mode == 'residual':# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            # residual block
            theta_b = self.theta_b(x).reshape(shape[0], shape[2], self.theta_dim)
            theta_f = self.theta_f(x).reshape(shape[0], shape[2], self.theta_dim)
            b = self.linear_b(theta_b).permute(0,2,1) # (batch, backcast length, feature_dim)
            f = self.linear_f(theta_f).permute(0,2,1) # (batch, forecast length, feature_dim)
        else:
            theta_b = self.theta(x).reshape(shape[0], self.theta_dim, shape[2])
            theta_f = theta_b

            if self.mode == 'trend':
                b = self.get_trend(theta_b, t_b)
                f = self.get_trend(theta_f, t_f)
                
            elif self.mode == 'seasonality':
                b = self.get_seasonality(theta_b, t_b)
                f = self.get_seasonality(theta_f, t_f)
        return b, f# We can simply call pairplot on our DataFrame for an automatic visual analysis 


    def get_trend(self, theta, t):
        # theta dim = 0 -> 수평선 (y=a)
        # theta dim = 1 -> 직선 (y=bx)
        # theta dim = 2 -> 이차곡선 (y=cx^2)
        # ...
        T = torch.stack([t ** i for i in range(theta.shape[1])])  # (theta_dim ,sequence length)
        out = torch.einsum('btf,ts->bsf', theta, T)
        return out


    def get_seasonality(self, theta, t):
        s1 = torch.stack([torch.cos(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()  # H/2-1
        s2 = torch.stack([torch.sin(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()
        S = torch.cat([s1, s2])# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        out = torch.einsum('btf,ts->bsf', theta, S)
        return out

# %%
# model hyper parameters
theta_dim=(2, 8, 3)
n_trend=3
n_seasonality=3
n_residual=3
hidden_dim=128


model = NBeatsNet(forecast_length, backcast_length, theta_dim, n_trend, n_seasonality, n_residual, hidden_dim)
model = model.cuda()

# We can simply call pairplot on our DataFrame for an automatic visual analysis

# %%
learning_rate = 1e-4

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
num_epoch = 500

import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        
        forecast = model(inputs)
    
        backcast, forecast = model(inputs)
        loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
            inputs = inputs.cuda()
            labels = labels.cuda()

            backcast, forecast = model(inputs)
            loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)
# Out:
# epoch [0/500] iter [000/016] loss [1.9062] elapsed time [0.00min]
# epoch [0/500] train loss [1.7340] validation loss [6.8617] elapsed time [0.02 min]
#
# epoch [1/500] iter [000/016] loss [1.6673] elapsed time [0.02min]
# epoch [1/500] train loss [1.4905] validation loss [5.7340] elapsed time [0.04 min]
#
# epoch [2/500] iter [000/016] loss [1.3769] elapsed time [0.04min]
# epoch [2/500] train loss [1.1887] validation loss [3.8718] elapsed time [0.06 min]
#
# epoch [3/500] iter [000/016] loss [1.0566] elapsed time [0.06min]
# epoch [3/500] train loss [0.9048] validation loss [2.2633] elapsed time [0.08 min]
#
# epoch [4/500] iter [000/016] loss [0.8063] elapsed time [0.08min]
# epoch [4/500] train loss [0.7257] validation loss [1.9574] elapsed time [0.10 min]
#
# epoch [5/500] iter [000/016] loss [0.6668] elapsed time [0.10min]
# epoch [5/500] train loss [0.6309] validation loss [2.0186] elapsed time [0.12 min]
#
# epoch [6/500] iter [000/016] loss [0.6105] elapsed time [0.12min]
# epoch [6/500] train loss [0.5807] validation loss [1.9048] elapsed time [0.14 min]
#
# epoch [7/500] iter [000/016] loss [0.5580] elapsed time [0.14min]
# epoch [7/500] train loss [0.5393] validation loss [1.7943] elapsed time [0.16 min]
#
# epoch [8/500] iter [000/016] loss [0.5281] elapsed time [0.16min]
# epoch [8/500] train loss [0.5061] validation loss [1.7349] elapsed time [0.18 min]
#
# epoch [9/500] iter [000/016] loss [0.4907] elapsed time [0.18min]
# epoch [9/500] train loss [0.4747] validation loss [1.7052] elapsed time [0.20 min]
#
# epoch [10/500] iter [000/016] loss [0.4600] elapsed time [0.20min]
# epoch [10/500] train loss [0.4506] validation loss [1.6534] elapsed time [0.22 min]
#
# epoch [11/500] iter [000/016] loss [0.4340] elapsed time [0.22min]
# epoch [11/500] train loss [0.4276] validation loss [1.5556] elapsed time [0.24 min]
#
# epoch [12/500] iter [000/016] loss [0.4137] elapsed time [0.25min]
# epoch [12/500] train loss [0.4057] validation loss [1.5175] elapsed time [0.26 min]
#
# epoch [13/500] iter [000/016] loss [0.4046] elapsed time [0.27min]
# epoch [13/500] train loss [0.3870] validation loss [1.4408] elapsed time [0.28 min]
#
# epoch [14/500] iter [000/016] loss [0.3728] elapsed time [0.29min]
# epoch [14/500] train loss [0.3691] validation loss [1.3596] elapsed time [0.30 min]
#
# epoch [15/500] iter [000/016] loss [0.3515] elapsed time [0.31min]
# epoch [15/500] train loss [0.3526] validation loss [1.3096] elapsed time [0.32 min]
#
# epoch [16/500] iter [000/016] loss [0.3439] elapsed time [0.33min]
# epoch [16/500] train loss [0.3360] validation loss [1.2988] elapsed time [0.34 min]
#
# epoch [17/500] iter [000/016] loss [0.3287] elapsed time [0.35min]
# epoch [17/500] train loss [0.3205] validation loss [1.2650] elapsed time [0.36 min]
#
# epoch [18/500] iter [000/016] loss [0.3087] elapsed time [0.37min]
# epoch [18/500] train loss [0.3059] validation loss [1.2494] elapsed time [0.38 min]
#
# epoch [19/500] iter [000/016] loss [0.2981] elapsed time [0.39min]
# epoch [19/500] train loss [0.2915] validation loss [1.2503] elapsed time [0.40 min]
#
# epoch [20/500] iter [000/016] loss [0.2853] elapsed time [0.41min]
# epoch [20/500] train loss [0.2776] validation loss [1.2028] elapsed time [0.42 min]
#
# epoch [21/500] iter [000/016] loss [0.2716] elapsed time [0.43min]
# epoch [21/500] train loss [0.2649] validation loss [1.1598] elapsed time [0.44 min]
#
# epoch [22/500] iter [000/016] loss [0.2582] elapsed time [0.45min]
# epoch [22/500] train loss [0.2516] validation loss [1.1041] elapsed time [0.46 min]
#
# epoch [23/500] iter [000/016] loss [0.2465] elapsed time [0.47min]
# epoch [23/500] train loss [0.2406] validation loss [1.1265] elapsed time [0.48 min]
#
# epoch [24/500] iter [000/016] loss [0.2367] elapsed time [0.49min]
# epoch [24/500] train loss [0.2299] validation loss [1.1689] elapsed time [0.50 min]
#
# epoch [25/500] iter [000/016] loss [0.2225] elapsed time [0.51min]
# epoch [25/500] train loss [0.2200] validation loss [1.0970] elapsed time [0.52 min]
#
# epoch [26/500] iter [000/016] loss [0.2064] elapsed time [0.53min]
# epoch [26/500] train loss [0.2084] validation loss [1.1025] elapsed time [0.54 min]
#
# epoch [27/500] iter [000/016] loss [0.1986] elapsed time [0.55min]
# epoch [27/500] train loss [0.1988] validation loss [1.0829] elapsed time [0.56 min]
#
# epoch [28/500] iter [000/016] loss [0.1946] elapsed time [0.57min]
# epoch [28/500] train loss [0.1909] validation loss [1.0697] elapsed time [0.58 min]
#
# epoch [29/500] iter [000/016] loss [0.1898] elapsed time [0.59min]
# epoch [29/500] train loss [0.1827] validation loss [1.1207] elapsed time [0.60 min]
#
# epoch [30/500] iter [000/016] loss [0.1786] elapsed time [0.61min]
# epoch [30/500] train loss [0.1758] validation loss [1.0506] elapsed time [0.62 min]
#
# epoch [31/500] iter [000/016] loss [0.1733] elapsed time [0.63min]
# epoch [31/500] train loss [0.1683] validation loss [1.0767] elapsed time [0.64 min]
#
# epoch [32/500] iter [000/016] loss [0.1714] elapsed time [0.65min]
# epoch [32/500] train loss [0.1617] validation loss [1.0861] elapsed time [0.66 min]
#
# epoch [33/500] iter [000/016] loss [0.1578] elapsed time [0.67min]
# epoch [33/500] train loss [0.1556] validation loss [1.0494] elapsed time [0.68 min]
#
# epoch [34/500] iter [000/016] loss [0.1577] elapsed time [0.69min]
# epoch [34/500] train loss [0.1511] validation loss [1.1241] elapsed time [0.70 min]
#
# epoch [35/500] iter [000/016] loss [0.1547] elapsed time [0.71min]
# epoch [35/500] train loss [0.1469] validation loss [1.0878] elapsed time [0.72 min]
#
# epoch [36/500] iter [000/016] loss [0.1422] elapsed time [0.73min]
# epoch [36/500] train loss [0.1428] validation loss [1.0756] elapsed time [0.74 min]
#
# epoch [37/500] iter [000/016] loss [0.1359] elapsed time [0.75min]
# epoch [37/500] train loss [0.1396] validation loss [1.0759] elapsed time [0.76 min]
#
# epoch [38/500] iter [000/016] loss [0.1427] elapsed time [0.77min]
# epoch [38/500] train loss [0.1359] validation loss [1.0810] elapsed time [0.78 min]
#
# epoch [39/500] iter [000/016] loss [0.1330] elapsed time [0.79min]
# epoch [39/500] train loss [0.1330] validation loss [1.1517] elapsed time [0.80 min]
#
# epoch [40/500] iter [000/016] loss [0.1335] elapsed time [0.81min]
# epoch [40/500] train loss [0.1303] validation loss [1.0929] elapsed time [0.82 min]
#
# epoch [41/500] iter [000/016] loss [0.1328] elapsed time [0.83min]
# epoch [41/500] train loss [0.1279] validation loss [1.1443] elapsed time [0.84 min]
#
# epoch [42/500] iter [000/016] loss [0.1178] elapsed time [0.85min]
# epoch [42/500] train loss [0.1260] validation loss [1.1491] elapsed time [0.86 min]
#
# epoch [43/500] iter [000/016] loss [0.1222] elapsed time [0.87min]
# epoch [43/500] train loss [0.1240] validation loss [1.0733] elapsed time [0.88 min]
#
# epoch [44/500] iter [000/016] loss [0.1246] elapsed time [0.89min]
# epoch [44/500] train loss [0.1231] validation loss [1.1321] elapsed time [0.90 min]
#
# epoch [45/500] iter [000/016] loss [0.1203] elapsed time [0.91min]
# epoch [45/500] train loss [0.1202] validation loss [1.1035] elapsed time [0.92 min]
#
# epoch [46/500] iter [000/016] loss [0.1104] elapsed time [0.93min]
# epoch [46/500] train loss [0.1173] validation loss [1.1109] elapsed time [0.94 min]
#
# epoch [47/500] iter [000/016] loss [0.1178] elapsed time [0.95min]
# epoch [47/500] train loss [0.1160] validation loss [1.1546] elapsed time [0.96 min]
#
# epoch [48/500] iter [000/016] loss [0.1138] elapsed time [0.97min]
# epoch [48/500] train loss [0.1138] validation loss [1.1134] elapsed time [0.98 min]
#
# epoch [49/500] iter [000/016] loss [0.1128] elapsed time [0.99min]
# epoch [49/500] train loss [0.1116] validation loss [1.0833] elapsed time [1.00 min]
#
# epoch [50/500] iter [000/016] loss [0.1189] elapsed time [1.01min]
# epoch [50/500] train loss [0.1096] validation loss [1.1112] elapsed time [1.02 min]
#
# epoch [51/500] iter [000/016] loss [0.1085] elapsed time [1.03min]
# epoch [51/500] train loss [0.1082] validation loss [1.1087] elapsed time [1.04 min]
#
# epoch [52/500] iter [000/016] loss [0.1105] elapsed time [1.05min]
# epoch [52/500] train loss [0.1066] validation loss [1.1286] elapsed time [1.06 min]
#
# epoch [53/500] iter [000/016] loss [0.1092] elapsed time [1.07min]
# epoch [53/500] train loss [0.1039] validation loss [1.1552] elapsed time [1.08 min]
#
# epoch [54/500] iter [000/016] loss [0.1051] elapsed time [1.09min]
# epoch [54/500] train loss [0.1020] validation loss [1.1750] elapsed time [1.10 min]
#
# epoch [55/500] iter [000/016] loss [0.1026] elapsed time [1.11min]
# epoch [55/500] train loss [0.0999] validation loss [1.1737] elapsed time [1.12 min]
#
# epoch [56/500] iter [000/016] loss [0.0980] elapsed time [1.13min]
# epoch [56/500] train loss [0.0993] validation loss [1.1589] elapsed time [1.14 min]
#
# epoch [57/500] iter [000/016] loss [0.0925] elapsed time [1.15min]
# epoch [57/500] train loss [0.0973] validation loss [1.2066] elapsed time [1.16 min]
#
# epoch [58/500] iter [000/016] loss [0.0959] elapsed time [1.17min]
# epoch [58/500] train loss [0.0955] validation loss [1.1495] elapsed time [1.18 min]
#
# epoch [59/500] iter [000/016] loss [0.1026] elapsed time [1.19min]
# epoch [59/500] train loss [0.0950] validation loss [1.1496] elapsed time [1.20 min]
#
# epoch [60/500] iter [000/016] loss [0.0979] elapsed time [1.21min]
# epoch [60/500] train loss [0.0937] validation loss [1.1856] elapsed time [1.22 min]
#
# epoch [61/500] iter [000/016] loss [0.0951] elapsed time [1.23min]
# epoch [61/500] train loss [0.0925] validation loss [1.2365] elapsed time [1.24 min]
#
# epoch [62/500] iter [000/016] loss [0.0902] elapsed time [1.25min]
# epoch [62/500] train loss [0.0925] validation loss [1.1907] elapsed time [1.27 min]
#
# epoch [63/500] iter [000/016] loss [0.0920] elapsed time [1.27min]
# epoch [63/500] train loss [0.0922] validation loss [1.1970] elapsed time [1.29 min]
#
# epoch [64/500] iter [000/016] loss [0.0902] elapsed time [1.29min]
# epoch [64/500] train loss [0.0922] validation loss [1.1858] elapsed time [1.31 min]
#
# epoch [65/500] iter [000/016] loss [0.0859] elapsed time [1.31min]
# epoch [65/500] train loss [0.0915] validation loss [1.2674] elapsed time [1.33 min]
#
# epoch [66/500] iter [000/016] loss [0.0863] elapsed time [1.33min]
# epoch [66/500] train loss [0.0908] validation loss [1.2122] elapsed time [1.35 min]
#
# epoch [67/500] iter [000/016] loss [0.0867] elapsed time [1.35min]
# epoch [67/500] train loss [0.0906] validation loss [1.2247] elapsed time [1.37 min]
#
# epoch [68/500] iter [000/016] loss [0.0914] elapsed time [1.37min]
# epoch [68/500] train loss [0.0903] validation loss [1.2024] elapsed time [1.39 min]
#
# epoch [69/500] iter [000/016] loss [0.0906] elapsed time [1.39min]
# epoch [69/500] train loss [0.0907] validation loss [1.1651] elapsed time [1.41 min]
#
# epoch [70/500] iter [000/016] loss [0.0849] elapsed time [1.41min]
# epoch [70/500] train loss [0.0896] validation loss [1.1975] elapsed time [1.43 min]
#
# epoch [71/500] iter [000/016] loss [0.0890] elapsed time [1.43min]
# epoch [71/500] train loss [0.0900] validation loss [1.1904] elapsed time [1.45 min]
#
# epoch [72/500] iter [000/016] loss [0.1008] elapsed time [1.45min]
# epoch [72/500] train loss [0.0889] validation loss [1.2301] elapsed time [1.47 min]
#
# epoch [73/500] iter [000/016] loss [0.0842] elapsed time [1.47min]
# epoch [73/500] train loss [0.0886] validation loss [1.2582] elapsed time [1.49 min]
#
# epoch [74/500] iter [000/016] loss [0.0889] elapsed time [1.49min]
# epoch [74/500] train loss [0.0892] validation loss [1.2367] elapsed time [1.51 min]
#
# epoch [75/500] iter [000/016] loss [0.0925] elapsed time [1.51min]
# epoch [75/500] train loss [0.0887] validation loss [1.2071] elapsed time [1.53 min]
#
# epoch [76/500] iter [000/016] loss [0.0830] elapsed time [1.53min]
# epoch [76/500] train loss [0.0882] validation loss [1.2151] elapsed time [1.55 min]
#
# epoch [77/500] iter [000/016] loss [0.0831] elapsed time [1.55min]
# epoch [77/500] train loss [0.0878] validation loss [1.2480] elapsed time [1.57 min]
#
# epoch [78/500] iter [000/016] loss [0.0790] elapsed time [1.57min]
# epoch [78/500] train loss [0.0874] validation loss [1.2165] elapsed time [1.59 min]
#
# epoch [79/500] iter [000/016] loss [0.0823] elapsed time [1.59min]
# epoch [79/500] train loss [0.0884] validation loss [1.2339] elapsed time [1.61 min]
#
# epoch [80/500] iter [000/016] loss [0.0869] elapsed time [1.62min]
# epoch [80/500] train loss [0.0875] validation loss [1.2223] elapsed time [1.63 min]
#
# epoch [81/500] iter [000/016] loss [0.0847] elapsed time [1.64min]
# epoch [81/500] train loss [0.0876] validation loss [1.2361] elapsed time [1.65 min]
#
# epoch [82/500] iter [000/016] loss [0.0839] elapsed time [1.66min]
# epoch [82/500] train loss [0.0869] validation loss [1.2009] elapsed time [1.67 min]
#
# epoch [83/500] iter [000/016] loss [0.0817] elapsed time [1.68min]
# epoch [83/500] train loss [0.0865] validation loss [1.2179] elapsed time [1.69 min]
#
# epoch [84/500] iter [000/016] loss [0.0898] elapsed time [1.70min]
# epoch [84/500] train loss [0.0865] validation loss [1.1549] elapsed time [1.71 min]
#
# epoch [85/500] iter [000/016] loss [0.0816] elapsed time [1.72min]
# epoch [85/500] train loss [0.0862] validation loss [1.2036] elapsed time [1.73 min]
#
# epoch [86/500] iter [000/016] loss [0.0814] elapsed time [1.74min]
# epoch [86/500] train loss [0.0863] validation loss [1.1912] elapsed time [1.75 min]
#
# epoch [87/500] iter [000/016] loss [0.0843] elapsed time [1.76min]
# epoch [87/500] train loss [0.0864] validation loss [1.2096] elapsed time [1.77 min]
#
# epoch [88/500] iter [000/016] loss [0.0873] elapsed time [1.78min]
# epoch [88/500] train loss [0.0867] validation loss [1.1785] elapsed time [1.79 min]
#
# epoch [89/500] iter [000/016] loss [0.0856] elapsed time [1.80min]
# epoch [89/500] train loss [0.0856] validation loss [1.2239] elapsed time [1.81 min]
#
# epoch [90/500] iter [000/016] loss [0.0858] elapsed time [1.82min]
# epoch [90/500] train loss [0.0850] validation loss [1.1719] elapsed time [1.84 min]
#
# epoch [91/500] iter [000/016] loss [0.0903] elapsed time [1.84min]
# epoch [91/500] train loss [0.0847] validation loss [1.2230] elapsed time [1.86 min]
#
# epoch [92/500] iter [000/016] loss [0.0845] elapsed time [1.86min]
# epoch [92/500] train loss [0.0848] validation loss [1.1285] elapsed time [1.88 min]
#
# epoch [93/500] iter [000/016] loss [0.0776] elapsed time [1.88min]
# epoch [93/500] train loss [0.0846] validation loss [1.2354] elapsed time [1.90 min]
#
# epoch [94/500] iter [000/016] loss [0.0880] elapsed time [1.90min]
# epoch [94/500] train loss [0.0839] validation loss [1.1706] elapsed time [1.92 min]
#
# epoch [95/500] iter [000/016] loss [0.0847] elapsed time [1.92min]
# epoch [95/500] train loss [0.0841] validation loss [1.1943] elapsed time [1.94 min]
#
# epoch [96/500] iter [000/016] loss [0.0840] elapsed time [1.94min]
# epoch [96/500] train loss [0.0842] validation loss [1.1901] elapsed time [1.96 min]
#
# epoch [97/500] iter [000/016] loss [0.0783] elapsed time [1.96min]
# epoch [97/500] train loss [0.0839] validation loss [1.1911] elapsed time [1.98 min]
#
# epoch [98/500] iter [000/016] loss [0.0831] elapsed time [1.98min]
# epoch [98/500] train loss [0.0829] validation loss [1.1842] elapsed time [2.00 min]
#
# epoch [99/500] iter [000/016] loss [0.0855] elapsed time [2.00min]
# epoch [99/500] train loss [0.0842] validation loss [1.2007] elapsed time [2.02 min]
#
# epoch [100/500] iter [000/016] loss [0.0846] elapsed time [2.02min]
# epoch [100/500] train loss [0.0837] validation loss [1.2141] elapsed time [2.04 min]
#
# epoch [101/500] iter [000/016] loss [0.0835] elapsed time [2.04min]
# epoch [101/500] train loss [0.0835] validation loss [1.1484] elapsed time [2.06 min]
#
# epoch [102/500] iter [000/016] loss [0.0880] elapsed time [2.07min]
# epoch [102/500] train loss [0.0831] validation loss [1.1645] elapsed time [2.08 min]
#
# epoch [103/500] iter [000/016] loss [0.0879] elapsed time [2.09min]
# epoch [103/500] train loss [0.0828] validation loss [1.1659] elapsed time [2.10 min]
#
# epoch [104/500] iter [000/016] loss [0.0812] elapsed time [2.11min]
# epoch [104/500] train loss [0.0825] validation loss [1.2308] elapsed time [2.12 min]
#
# epoch [105/500] iter [000/016] loss [0.0823] elapsed time [2.13min]
# epoch [105/500] train loss [0.0829] validation loss [1.1139] elapsed time [2.14 min]
#
# epoch [106/500] iter [000/016] loss [0.0859] elapsed time [2.15min]
# epoch [106/500] train loss [0.0825] validation loss [1.1775] elapsed time [2.16 min]
#
# epoch [107/500] iter [000/016] loss [0.0813] elapsed time [2.17min]
# epoch [107/500] train loss [0.0822] validation loss [1.1116] elapsed time [2.18 min]
#
# epoch [108/500] iter [000/016] loss [0.0787] elapsed time [2.19min]
# epoch [108/500] train loss [0.0819] validation loss [1.1324] elapsed time [2.20 min]
#
# epoch [109/500] iter [000/016] loss [0.0760] elapsed time [2.21min]
# epoch [109/500] train loss [0.0822] validation loss [1.1581] elapsed time [2.22 min]
#
# epoch [110/500] iter [000/016] loss [0.0793] elapsed time [2.23min]
# epoch [110/500] train loss [0.0811] validation loss [1.1383] elapsed time [2.24 min]
#
# epoch [111/500] iter [000/016] loss [0.0843] elapsed time [2.25min]
# epoch [111/500] train loss [0.0813] validation loss [1.1578] elapsed time [2.26 min]
#
# epoch [112/500] iter [000/016] loss [0.0802] elapsed time [2.27min]
# epoch [112/500] train loss [0.0813] validation loss [1.1608] elapsed time [2.28 min]
#
# epoch [113/500] iter [000/016] loss [0.0795] elapsed time [2.29min]
# epoch [113/500] train loss [0.0809] validation loss [1.1778] elapsed time [2.30 min]
#
# epoch [114/500] iter [000/016] loss [0.0854] elapsed time [2.31min]
# epoch [114/500] train loss [0.0814] validation loss [1.1323] elapsed time [2.32 min]
#
# epoch [115/500] iter [000/016] loss [0.0777] elapsed time [2.33min]
# epoch [115/500] train loss [0.0814] validation loss [1.1746] elapsed time [2.34 min]
#
# epoch [116/500] iter [000/016] loss [0.0820] elapsed time [2.35min]
# epoch [116/500] train loss [0.0814] validation loss [1.1458] elapsed time [2.36 min]
#
# epoch [117/500] iter [000/016] loss [0.0818] elapsed time [2.37min]
# epoch [117/500] train loss [0.0805] validation loss [1.1163] elapsed time [2.38 min]
#
# epoch [118/500] iter [000/016] loss [0.0823] elapsed time [2.39min]
# epoch [118/500] train loss [0.0810] validation loss [1.1294] elapsed time [2.41 min]
#
# epoch [119/500] iter [000/016] loss [0.0773] elapsed time [2.41min]
# epoch [119/500] train loss [0.0806] validation loss [1.1183] elapsed time [2.43 min]
#
# epoch [120/500] iter [000/016] loss [0.0829] elapsed time [2.43min]
# epoch [120/500] train loss [0.0806] validation loss [1.1617] elapsed time [2.45 min]
#
# epoch [121/500] iter [000/016] loss [0.0744] elapsed time [2.45min]
# epoch [121/500] train loss [0.0801] validation loss [1.1297] elapsed time [2.47 min]
#
# epoch [122/500] iter [000/016] loss [0.0817] elapsed time [2.47min]
# epoch [122/500] train loss [0.0805] validation loss [1.1398] elapsed time [2.49 min]
#
# epoch [123/500] iter [000/016] loss [0.0770] elapsed time [2.49min]
# epoch [123/500] train loss [0.0796] validation loss [1.1167] elapsed time [2.51 min]
#
# epoch [124/500] iter [000/016] loss [0.0815] elapsed time [2.51min]
# epoch [124/500] train loss [0.0798] validation loss [1.1388] elapsed time [2.53 min]
#
# epoch [125/500] iter [000/016] loss [0.0846] elapsed time [2.53min]
# epoch [125/500] train loss [0.0803] validation loss [1.0805] elapsed time [2.55 min]
#
# epoch [126/500] iter [000/016] loss [0.0748] elapsed time [2.55min]
# epoch [126/500] train loss [0.0800] validation loss [1.1275] elapsed time [2.57 min]
#
# epoch [127/500] iter [000/016] loss [0.0815] elapsed time [2.57min]
# epoch [127/500] train loss [0.0798] validation loss [1.0729] elapsed time [2.59 min]
#
# epoch [128/500] iter [000/016] loss [0.0750] elapsed time [2.59min]
# epoch [128/500] train loss [0.0794] validation loss [1.0694] elapsed time [2.61 min]
#
# epoch [129/500] iter [000/016] loss [0.0797] elapsed time [2.61min]
# epoch [129/500] train loss [0.0790] validation loss [1.1047] elapsed time [2.63 min]
#
# epoch [130/500] iter [000/016] loss [0.0794] elapsed time [2.63min]
# epoch [130/500] train loss [0.0787] validation loss [1.1087] elapsed time [2.65 min]
#
# epoch [131/500] iter [000/016] loss [0.0768] elapsed time [2.65min]
# epoch [131/500] train loss [0.0795] validation loss [1.0718] elapsed time [2.67 min]
#
# epoch [132/500] iter [000/016] loss [0.0824] elapsed time [2.67min]
# epoch [132/500] train loss [0.0784] validation loss [1.1144] elapsed time [2.69 min]
#
# epoch [133/500] iter [000/016] loss [0.0759] elapsed time [2.69min]
# epoch [133/500] train loss [0.0793] validation loss [1.0989] elapsed time [2.71 min]
#
# epoch [134/500] iter [000/016] loss [0.0793] elapsed time [2.71min]
# epoch [134/500] train loss [0.0791] validation loss [1.0673] elapsed time [2.73 min]
#
# epoch [135/500] iter [000/016] loss [0.0792] elapsed time [2.73min]
# epoch [135/500] train loss [0.0793] validation loss [1.0840] elapsed time [2.75 min]
#
# epoch [136/500] iter [000/016] loss [0.0819] elapsed time [2.76min]
# epoch [136/500] train loss [0.0781] validation loss [1.0864] elapsed time [2.77 min]
#
# epoch [137/500] iter [000/016] loss [0.0804] elapsed time [2.78min]
# epoch [137/500] train loss [0.0780] validation loss [1.0852] elapsed time [2.79 min]
#
# epoch [138/500] iter [000/016] loss [0.0805] elapsed time [2.80min]
# epoch [138/500] train loss [0.0778] validation loss [1.1130] elapsed time [2.81 min]
#
# epoch [139/500] iter [000/016] loss [0.0748] elapsed time [2.82min]
# epoch [139/500] train loss [0.0784] validation loss [1.0909] elapsed time [2.83 min]
#
# epoch [140/500] iter [000/016] loss [0.0769] elapsed time [2.84min]
# epoch [140/500] train loss [0.0781] validation loss [1.0563] elapsed time [2.85 min]
#
# epoch [141/500] iter [000/016] loss [0.0773] elapsed time [2.86min]
# epoch [141/500] train loss [0.0784] validation loss [1.0748] elapsed time [2.87 min]
#
# epoch [142/500] iter [000/016] loss [0.0798] elapsed time [2.88min]
# epoch [142/500] train loss [0.0781] validation loss [1.0758] elapsed time [2.89 min]
#
# epoch [143/500] iter [000/016] loss [0.0776] elapsed time [2.90min]
# epoch [143/500] train loss [0.0778] validation loss [1.0734] elapsed time [2.91 min]
#
# epoch [144/500] iter [000/016] loss [0.0765] elapsed time [2.92min]
# epoch [144/500] train loss [0.0774] validation loss [1.0659] elapsed time [2.93 min]
#
# epoch [145/500] iter [000/016] loss [0.0768] elapsed time [2.94min]
# epoch [145/500] train loss [0.0780] validation loss [1.0757] elapsed time [2.95 min]
#
# epoch [146/500] iter [000/016] loss [0.0765] elapsed time [2.96min]
# epoch [146/500] train loss [0.0783] validation loss [1.0248] elapsed time [2.97 min]
#
# epoch [147/500] iter [000/016] loss [0.0791] elapsed time [2.98min]
# epoch [147/500] train loss [0.0786] validation loss [1.0989] elapsed time [2.99 min]
#
# epoch [148/500] iter [000/016] loss [0.0750] elapsed time [3.00min]
# epoch [148/500] train loss [0.0777] validation loss [1.0628] elapsed time [3.01 min]
#
# epoch [149/500] iter [000/016] loss [0.0782] elapsed time [3.02min]
# epoch [149/500] train loss [0.0771] validation loss [1.0612] elapsed time [3.03 min]
#
# epoch [150/500] iter [000/016] loss [0.0766] elapsed time [3.04min]
# epoch [150/500] train loss [0.0767] validation loss [1.0532] elapsed time [3.05 min]
#
# epoch [151/500] iter [000/016] loss [0.0796] elapsed time [3.06min]
# epoch [151/500] train loss [0.0767] validation loss [1.0690] elapsed time [3.08 min]
#
# epoch [152/500] iter [000/016] loss [0.0784] elapsed time [3.08min]
# epoch [152/500] train loss [0.0768] validation loss [1.0437] elapsed time [3.10 min]
#
# epoch [153/500] iter [000/016] loss [0.0716] elapsed time [3.10min]
# epoch [153/500] train loss [0.0762] validation loss [1.1083] elapsed time [3.12 min]
#
# epoch [154/500] iter [000/016] loss [0.0802] elapsed time [3.12min]
# epoch [154/500] train loss [0.0760] validation loss [1.0697] elapsed time [3.14 min]
#
# epoch [155/500] iter [000/016] loss [0.0818] elapsed time [3.14min]
# epoch [155/500] train loss [0.0764] validation loss [1.0590] elapsed time [3.16 min]
#
# epoch [156/500] iter [000/016] loss [0.0746] elapsed time [3.16min]
# epoch [156/500] train loss [0.0762] validation loss [1.0666] elapsed time [3.18 min]
#
# epoch [157/500] iter [000/016] loss [0.0769] elapsed time [3.18min]
# epoch [157/500] train loss [0.0766] validation loss [1.0412] elapsed time [3.20 min]
#
# epoch [158/500] iter [000/016] loss [0.0758] elapsed time [3.20min]
# epoch [158/500] train loss [0.0762] validation loss [1.0514] elapsed time [3.22 min]
#
# epoch [159/500] iter [000/016] loss [0.0755] elapsed time [3.22min]
# epoch [159/500] train loss [0.0760] validation loss [1.0686] elapsed time [3.24 min]
#
# epoch [160/500] iter [000/016] loss [0.0759] elapsed time [3.25min]
# epoch [160/500] train loss [0.0761] validation loss [1.0300] elapsed time [3.26 min]
#
# epoch [161/500] iter [000/016] loss [0.0742] elapsed time [3.27min]
# epoch [161/500] train loss [0.0759] validation loss [1.0796] elapsed time [3.28 min]
#
# epoch [162/500] iter [000/016] loss [0.0695] elapsed time [3.29min]
# epoch [162/500] train loss [0.0755] validation loss [1.0507] elapsed time [3.30 min]
#
# epoch [163/500] iter [000/016] loss [0.0738] elapsed time [3.31min]
# epoch [163/500] train loss [0.0756] validation loss [1.0483] elapsed time [3.32 min]
#
# epoch [164/500] iter [000/016] loss [0.0770] elapsed time [3.33min]
# epoch [164/500] train loss [0.0757] validation loss [1.0785] elapsed time [3.34 min]
#
# epoch [165/500] iter [000/016] loss [0.0739] elapsed time [3.35min]
# epoch [165/500] train loss [0.0758] validation loss [1.0436] elapsed time [3.37 min]
#
# epoch [166/500] iter [000/016] loss [0.0723] elapsed time [3.37min]
# epoch [166/500] train loss [0.0759] validation loss [1.0441] elapsed time [3.39 min]
#
# epoch [167/500] iter [000/016] loss [0.0734] elapsed time [3.39min]
# epoch [167/500] train loss [0.0762] validation loss [1.0269] elapsed time [3.41 min]
#
# epoch [168/500] iter [000/016] loss [0.0810] elapsed time [3.41min]
# epoch [168/500] train loss [0.0756] validation loss [1.0257] elapsed time [3.43 min]
#
# epoch [169/500] iter [000/016] loss [0.0760] elapsed time [3.43min]
# epoch [169/500] train loss [0.0751] validation loss [1.0260] elapsed time [3.45 min]
#
# epoch [170/500] iter [000/016] loss [0.0773] elapsed time [3.46min]
# epoch [170/500] train loss [0.0751] validation loss [1.0696] elapsed time [3.47 min]
#
# epoch [171/500] iter [000/016] loss [0.0755] elapsed time [3.48min]
# epoch [171/500] train loss [0.0753] validation loss [1.0346] elapsed time [3.49 min]
#
# epoch [172/500] iter [000/016] loss [0.0780] elapsed time [3.50min]
# epoch [172/500] train loss [0.0756] validation loss [1.0445] elapsed time [3.52 min]
#
# epoch [173/500] iter [000/016] loss [0.0799] elapsed time [3.52min]
# epoch [173/500] train loss [0.0757] validation loss [1.0073] elapsed time [3.54 min]
#
# epoch [174/500] iter [000/016] loss [0.0736] elapsed time [3.54min]
# epoch [174/500] train loss [0.0753] validation loss [1.0746] elapsed time [3.56 min]
#
# epoch [175/500] iter [000/016] loss [0.0725] elapsed time [3.56min]
# epoch [175/500] train loss [0.0754] validation loss [1.0274] elapsed time [3.58 min]
#
# epoch [176/500] iter [000/016] loss [0.0745] elapsed time [3.59min]
# epoch [176/500] train loss [0.0749] validation loss [1.0323] elapsed time [3.60 min]
#
# epoch [177/500] iter [000/016] loss [0.0710] elapsed time [3.61min]
# epoch [177/500] train loss [0.0745] validation loss [1.0109] elapsed time [3.63 min]
#
# epoch [178/500] iter [000/016] loss [0.0739] elapsed time [3.63min]
# epoch [178/500] train loss [0.0752] validation loss [1.0409] elapsed time [3.65 min]
#
# epoch [179/500] iter [000/016] loss [0.0742] elapsed time [3.65min]
# epoch [179/500] train loss [0.0742] validation loss [1.0372] elapsed time [3.67 min]
#
# epoch [180/500] iter [000/016] loss [0.0770] elapsed time [3.67min]
# epoch [180/500] train loss [0.0748] validation loss [1.0180] elapsed time [3.69 min]
#
# epoch [181/500] iter [000/016] loss [0.0756] elapsed time [3.69min]
# epoch [181/500] train loss [0.0740] validation loss [1.0207] elapsed time [3.71 min]
#
# epoch [182/500] iter [000/016] loss [0.0703] elapsed time [3.71min]
# epoch [182/500] train loss [0.0748] validation loss [1.0198] elapsed time [3.73 min]
#
# epoch [183/500] iter [000/016] loss [0.0718] elapsed time [3.73min]
# epoch [183/500] train loss [0.0743] validation loss [1.0543] elapsed time [3.75 min]
#
# epoch [184/500] iter [000/016] loss [0.0715] elapsed time [3.76min]
# epoch [184/500] train loss [0.0742] validation loss [1.0221] elapsed time [3.77 min]
#
# epoch [185/500] iter [000/016] loss [0.0722] elapsed time [3.78min]
# epoch [185/500] train loss [0.0738] validation loss [1.0173] elapsed time [3.79 min]
#
# epoch [186/500] iter [000/016] loss [0.0770] elapsed time [3.80min]
# epoch [186/500] train loss [0.0740] validation loss [1.0029] elapsed time [3.82 min]
#
# epoch [187/500] iter [000/016] loss [0.0723] elapsed time [3.82min]
# epoch [187/500] train loss [0.0744] validation loss [1.0174] elapsed time [3.84 min]
#
# epoch [188/500] iter [000/016] loss [0.0724] elapsed time [3.84min]
# epoch [188/500] train loss [0.0737] validation loss [1.0430] elapsed time [3.86 min]
#
# epoch [189/500] iter [000/016] loss [0.0737] elapsed time [3.86min]
# epoch [189/500] train loss [0.0732] validation loss [1.0220] elapsed time [3.88 min]
#
# epoch [190/500] iter [000/016] loss [0.0711] elapsed time [3.88min]
# epoch [190/500] train loss [0.0740] validation loss [1.0079] elapsed time [3.90 min]
#
# epoch [191/500] iter [000/016] loss [0.0720] elapsed time [3.91min]
# epoch [191/500] train loss [0.0736] validation loss [1.0032] elapsed time [3.92 min]
#
# epoch [192/500] iter [000/016] loss [0.0664] elapsed time [3.93min]
# epoch [192/500] train loss [0.0741] validation loss [1.0351] elapsed time [3.94 min]
#
# epoch [193/500] iter [000/016] loss [0.0737] elapsed time [3.95min]
# epoch [193/500] train loss [0.0733] validation loss [1.0072] elapsed time [3.96 min]
#
# epoch [194/500] iter [000/016] loss [0.0746] elapsed time [3.97min]
# epoch [194/500] train loss [0.0735] validation loss [1.0058] elapsed time [3.99 min]
#
# epoch [195/500] iter [000/016] loss [0.0708] elapsed time [3.99min]
# epoch [195/500] train loss [0.0731] validation loss [1.0285] elapsed time [4.01 min]
#
# epoch [196/500] iter [000/016] loss [0.0751] elapsed time [4.01min]
# epoch [196/500] train loss [0.0730] validation loss [1.0694] elapsed time [4.03 min]
#
# epoch [197/500] iter [000/016] loss [0.0728] elapsed time [4.03min]
# epoch [197/500] train loss [0.0734] validation loss [1.0362] elapsed time [4.05 min]
#
# epoch [198/500] iter [000/016] loss [0.0690] elapsed time [4.05min]
# epoch [198/500] train loss [0.0734] validation loss [1.0054] elapsed time [4.07 min]
#
# epoch [199/500] iter [000/016] loss [0.0676] elapsed time [4.08min]
# epoch [199/500] train loss [0.0730] validation loss [1.0207] elapsed time [4.09 min]
#
# epoch [200/500] iter [000/016] loss [0.0733] elapsed time [4.10min]
# epoch [200/500] train loss [0.0730] validation loss [1.0046] elapsed time [4.11 min]
#
# epoch [201/500] iter [000/016] loss [0.0733] elapsed time [4.12min]
# epoch [201/500] train loss [0.0725] validation loss [1.0213] elapsed time [4.14 min]
#
# epoch [202/500] iter [000/016] loss [0.0768] elapsed time [4.14min]
# epoch [202/500] train loss [0.0735] validation loss [1.0291] elapsed time [4.16 min]
#
# epoch [203/500] iter [000/016] loss [0.0748] elapsed time [4.16min]
# epoch [203/500] train loss [0.0734] validation loss [1.0065] elapsed time [4.18 min]
#
# epoch [204/500] iter [000/016] loss [0.0752] elapsed time [4.18min]
# epoch [204/500] train loss [0.0728] validation loss [1.0104] elapsed time [4.20 min]
#
# epoch [205/500] iter [000/016] loss [0.0737] elapsed time [4.20min]
# epoch [205/500] train loss [0.0731] validation loss [1.0397] elapsed time [4.22 min]
#
# epoch [206/500] iter [000/016] loss [0.0683] elapsed time [4.22min]
# epoch [206/500] train loss [0.0727] validation loss [1.0028] elapsed time [4.24 min]
#
# epoch [207/500] iter [000/016] loss [0.0735] elapsed time [4.24min]
# epoch [207/500] train loss [0.0719] validation loss [1.0310] elapsed time [4.26 min]
#
# epoch [208/500] iter [000/016] loss [0.0743] elapsed time [4.26min]
# epoch [208/500] train loss [0.0736] validation loss [1.0051] elapsed time [4.28 min]
#
# epoch [209/500] iter [000/016] loss [0.0767] elapsed time [4.28min]
# epoch [209/500] train loss [0.0740] validation loss [1.0235] elapsed time [4.30 min]
#
# epoch [210/500] iter [000/016] loss [0.0733] elapsed time [4.30min]
# epoch [210/500] train loss [0.0729] validation loss [0.9959] elapsed time [4.32 min]
#
# epoch [211/500] iter [000/016] loss [0.0739] elapsed time [4.32min]
# epoch [211/500] train loss [0.0729] validation loss [1.0330] elapsed time [4.34 min]
#
# epoch [212/500] iter [000/016] loss [0.0767] elapsed time [4.35min]
# epoch [212/500] train loss [0.0723] validation loss [1.0155] elapsed time [4.36 min]
#
# epoch [213/500] iter [000/016] loss [0.0734] elapsed time [4.37min]
# epoch [213/500] train loss [0.0717] validation loss [1.0199] elapsed time [4.38 min]
#
# epoch [214/500] iter [000/016] loss [0.0725] elapsed time [4.39min]
# epoch [214/500] train loss [0.0717] validation loss [0.9991] elapsed time [4.40 min]
#
# epoch [215/500] iter [000/016] loss [0.0730] elapsed time [4.41min]
# epoch [215/500] train loss [0.0713] validation loss [1.0208] elapsed time [4.42 min]
#
# epoch [216/500] iter [000/016] loss [0.0714] elapsed time [4.43min]
# epoch [216/500] train loss [0.0719] validation loss [0.9982] elapsed time [4.44 min]
#
# epoch [217/500] iter [000/016] loss [0.0672] elapsed time [4.45min]
# epoch [217/500] train loss [0.0721] validation loss [1.0110] elapsed time [4.46 min]
#
# epoch [218/500] iter [000/016] loss [0.0736] elapsed time [4.47min]
# epoch [218/500] train loss [0.0717] validation loss [1.0039] elapsed time [4.48 min]
#
# epoch [219/500] iter [000/016] loss [0.0765] elapsed time [4.49min]
# epoch [219/500] train loss [0.0714] validation loss [1.0256] elapsed time [4.50 min]
#
# epoch [220/500] iter [000/016] loss [0.0691] elapsed time [4.51min]
# epoch [220/500] train loss [0.0720] validation loss [1.0239] elapsed time [4.52 min]
#
# epoch [221/500] iter [000/016] loss [0.0677] elapsed time [4.53min]
# epoch [221/500] train loss [0.0716] validation loss [1.0161] elapsed time [4.55 min]
#
# epoch [222/500] iter [000/016] loss [0.0713] elapsed time [4.55min]
# epoch [222/500] train loss [0.0716] validation loss [1.0199] elapsed time [4.57 min]
#
# epoch [223/500] iter [000/016] loss [0.0715] elapsed time [4.57min]
# epoch [223/500] train loss [0.0709] validation loss [1.0286] elapsed time [4.59 min]
#
# epoch [224/500] iter [000/016] loss [0.0744] elapsed time [4.59min]
# epoch [224/500] train loss [0.0714] validation loss [1.0194] elapsed time [4.61 min]
#
# epoch [225/500] iter [000/016] loss [0.0732] elapsed time [4.61min]
# epoch [225/500] train loss [0.0707] validation loss [1.0211] elapsed time [4.63 min]
#
# epoch [226/500] iter [000/016] loss [0.0726] elapsed time [4.63min]
# epoch [226/500] train loss [0.0710] validation loss [1.0250] elapsed time [4.65 min]
#
# epoch [227/500] iter [000/016] loss [0.0735] elapsed time [4.65min]
# epoch [227/500] train loss [0.0710] validation loss [1.0331] elapsed time [4.67 min]
#
# epoch [228/500] iter [000/016] loss [0.0674] elapsed time [4.67min]
# epoch [228/500] train loss [0.0718] validation loss [1.0137] elapsed time [4.69 min]
#
# epoch [229/500] iter [000/016] loss [0.0774] elapsed time [4.69min]
# epoch [229/500] train loss [0.0711] validation loss [1.0315] elapsed time [4.71 min]
#
# epoch [230/500] iter [000/016] loss [0.0721] elapsed time [4.71min]
# epoch [230/500] train loss [0.0709] validation loss [1.0175] elapsed time [4.73 min]
#
# epoch [231/500] iter [000/016] loss [0.0718] elapsed time [4.74min]
# epoch [231/500] train loss [0.0709] validation loss [1.0143] elapsed time [4.75 min]
#
# epoch [232/500] iter [000/016] loss [0.0679] elapsed time [4.76min]
# epoch [232/500] train loss [0.0706] validation loss [1.0072] elapsed time [4.77 min]
#
# epoch [233/500] iter [000/016] loss [0.0717] elapsed time [4.78min]
# epoch [233/500] train loss [0.0705] validation loss [1.0051] elapsed time [4.79 min]
#
# epoch [234/500] iter [000/016] loss [0.0682] elapsed time [4.80min]
# epoch [234/500] train loss [0.0706] validation loss [1.0110] elapsed time [4.81 min]
#
# epoch [235/500] iter [000/016] loss [0.0691] elapsed time [4.82min]
# epoch [235/500] train loss [0.0707] validation loss [1.0233] elapsed time [4.83 min]
#
# epoch [236/500] iter [000/016] loss [0.0703] elapsed time [4.84min]
# epoch [236/500] train loss [0.0702] validation loss [1.0371] elapsed time [4.86 min]
#
# epoch [237/500] iter [000/016] loss [0.0717] elapsed time [4.86min]
# epoch [237/500] train loss [0.0705] validation loss [1.0400] elapsed time [4.88 min]
#
# epoch [238/500] iter [000/016] loss [0.0701] elapsed time [4.88min]
# epoch [238/500] train loss [0.0704] validation loss [1.0608] elapsed time [4.90 min]
#
# epoch [239/500] iter [000/016] loss [0.0736] elapsed time [4.90min]
# epoch [239/500] train loss [0.0710] validation loss [1.0154] elapsed time [4.92 min]
#
# epoch [240/500] iter [000/016] loss [0.0686] elapsed time [4.92min]
# epoch [240/500] train loss [0.0705] validation loss [1.0634] elapsed time [4.94 min]
#
# epoch [241/500] iter [000/016] loss [0.0702] elapsed time [4.94min]
# epoch [241/500] train loss [0.0704] validation loss [1.0353] elapsed time [4.96 min]
#
# epoch [242/500] iter [000/016] loss [0.0752] elapsed time [4.96min]
# epoch [242/500] train loss [0.0697] validation loss [1.0375] elapsed time [4.98 min]
#
# epoch [243/500] iter [000/016] loss [0.0687] elapsed time [4.98min]
# epoch [243/500] train loss [0.0704] validation loss [1.0278] elapsed time [5.00 min]
#
# epoch [244/500] iter [000/016] loss [0.0686] elapsed time [5.00min]
# epoch [244/500] train loss [0.0704] validation loss [1.0324] elapsed time [5.02 min]
#
# epoch [245/500] iter [000/016] loss [0.0698] elapsed time [5.02min]
# epoch [245/500] train loss [0.0697] validation loss [1.0194] elapsed time [5.04 min]
#
# epoch [246/500] iter [000/016] loss [0.0730] elapsed time [5.04min]
# epoch [246/500] train loss [0.0694] validation loss [1.0600] elapsed time [5.06 min]
#
# epoch [247/500] iter [000/016] loss [0.0728] elapsed time [5.06min]
# epoch [247/500] train loss [0.0705] validation loss [1.0427] elapsed time [5.08 min]
#
# epoch [248/500] iter [000/016] loss [0.0723] elapsed time [5.08min]
# epoch [248/500] train loss [0.0702] validation loss [1.0305] elapsed time [5.10 min]
#
# epoch [249/500] iter [000/016] loss [0.0724] elapsed time [5.11min]
# epoch [249/500] train loss [0.0707] validation loss [1.0429] elapsed time [5.12 min]
#
# epoch [250/500] iter [000/016] loss [0.0708] elapsed time [5.13min]
# epoch [250/500] train loss [0.0701] validation loss [1.0310] elapsed time [5.14 min]
#
# epoch [251/500] iter [000/016] loss [0.0707] elapsed time [5.15min]
# epoch [251/500] train loss [0.0697] validation loss [0.9986] elapsed time [5.16 min]
#
# epoch [252/500] iter [000/016] loss [0.0804] elapsed time [5.17min]
# epoch [252/500] train loss [0.0699] validation loss [1.0314] elapsed time [5.18 min]
#
# epoch [253/500] iter [000/016] loss [0.0686] elapsed time [5.19min]
# epoch [253/500] train loss [0.0689] validation loss [1.0315] elapsed time [5.20 min]
#
# epoch [254/500] iter [000/016] loss [0.0671] elapsed time [5.21min]
# epoch [254/500] train loss [0.0690] validation loss [1.0439] elapsed time [5.22 min]
#
# epoch [255/500] iter [000/016] loss [0.0713] elapsed time [5.23min]
# epoch [255/500] train loss [0.0693] validation loss [1.0541] elapsed time [5.25 min]
#
# epoch [256/500] iter [000/016] loss [0.0687] elapsed time [5.25min]
# epoch [256/500] train loss [0.0691] validation loss [1.0232] elapsed time [5.27 min]
#
# epoch [257/500] iter [000/016] loss [0.0727] elapsed time [5.27min]
# epoch [257/500] train loss [0.0689] validation loss [1.0246] elapsed time [5.29 min]
#
# epoch [258/500] iter [000/016] loss [0.0723] elapsed time [5.29min]
# epoch [258/500] train loss [0.0688] validation loss [1.0082] elapsed time [5.31 min]
#
# epoch [259/500] iter [000/016] loss [0.0721] elapsed time [5.31min]
# epoch [259/500] train loss [0.0692] validation loss [1.0222] elapsed time [5.33 min]
#
# epoch [260/500] iter [000/016] loss [0.0685] elapsed time [5.33min]
# epoch [260/500] train loss [0.0692] validation loss [1.0350] elapsed time [5.35 min]
#
# epoch [261/500] iter [000/016] loss [0.0647] elapsed time [5.35min]
# epoch [261/500] train loss [0.0694] validation loss [1.0164] elapsed time [5.37 min]
#
# epoch [262/500] iter [000/016] loss [0.0664] elapsed time [5.37min]
# epoch [262/500] train loss [0.0688] validation loss [1.0473] elapsed time [5.39 min]
#
# epoch [263/500] iter [000/016] loss [0.0699] elapsed time [5.39min]
# epoch [263/500] train loss [0.0691] validation loss [1.0604] elapsed time [5.41 min]
#
# epoch [264/500] iter [000/016] loss [0.0683] elapsed time [5.41min]
# epoch [264/500] train loss [0.0688] validation loss [1.0287] elapsed time [5.43 min]
#
# epoch [265/500] iter [000/016] loss [0.0696] elapsed time [5.44min]
# epoch [265/500] train loss [0.0688] validation loss [1.0196] elapsed time [5.45 min]
#
# epoch [266/500] iter [000/016] loss [0.0672] elapsed time [5.46min]
# epoch [266/500] train loss [0.0691] validation loss [1.0364] elapsed time [5.47 min]
#
# epoch [267/500] iter [000/016] loss [0.0666] elapsed time [5.48min]
# epoch [267/500] train loss [0.0688] validation loss [1.0389] elapsed time [5.49 min]
#
# epoch [268/500] iter [000/016] loss [0.0643] elapsed time [5.50min]
# epoch [268/500] train loss [0.0684] validation loss [1.0237] elapsed time [5.51 min]
#
# epoch [269/500] iter [000/016] loss [0.0728] elapsed time [5.52min]
# epoch [269/500] train loss [0.0686] validation loss [1.0209] elapsed time [5.53 min]
#
# epoch [270/500] iter [000/016] loss [0.0656] elapsed time [5.54min]
# epoch [270/500] train loss [0.0684] validation loss [1.0488] elapsed time [5.56 min]
#
# epoch [271/500] iter [000/016] loss [0.0684] elapsed time [5.56min]
# epoch [271/500] train loss [0.0685] validation loss [1.0476] elapsed time [5.58 min]
#
# epoch [272/500] iter [000/016] loss [0.0692] elapsed time [5.58min]
# epoch [272/500] train loss [0.0682] validation loss [1.0426] elapsed time [5.60 min]
#
# epoch [273/500] iter [000/016] loss [0.0688] elapsed time [5.60min]
# epoch [273/500] train loss [0.0692] validation loss [1.0357] elapsed time [5.62 min]
#
# epoch [274/500] iter [000/016] loss [0.0708] elapsed time [5.62min]
# epoch [274/500] train loss [0.0687] validation loss [1.0479] elapsed time [5.64 min]
#
# epoch [275/500] iter [000/016] loss [0.0730] elapsed time [5.64min]
# epoch [275/500] train loss [0.0688] validation loss [1.0387] elapsed time [5.66 min]
#
# epoch [276/500] iter [000/016] loss [0.0701] elapsed time [5.66min]
# epoch [276/500] train loss [0.0685] validation loss [1.0248] elapsed time [5.68 min]
#
# epoch [277/500] iter [000/016] loss [0.0692] elapsed time [5.68min]
# epoch [277/500] train loss [0.0685] validation loss [1.0215] elapsed time [5.70 min]
#
# epoch [278/500] iter [000/016] loss [0.0675] elapsed time [5.70min]
# epoch [278/500] train loss [0.0685] validation loss [1.0327] elapsed time [5.72 min]
#
# epoch [279/500] iter [000/016] loss [0.0667] elapsed time [5.73min]
# epoch [279/500] train loss [0.0687] validation loss [1.0301] elapsed time [5.74 min]
#
# epoch [280/500] iter [000/016] loss [0.0733] elapsed time [5.75min]
# epoch [280/500] train loss [0.0680] validation loss [1.0429] elapsed time [5.76 min]
#
# epoch [281/500] iter [000/016] loss [0.0674] elapsed time [5.77min]
# epoch [281/500] train loss [0.0680] validation loss [1.0493] elapsed time [5.78 min]
#
# epoch [282/500] iter [000/016] loss [0.0683] elapsed time [5.79min]
# epoch [282/500] train loss [0.0677] validation loss [1.0618] elapsed time [5.80 min]
#
# epoch [283/500] iter [000/016] loss [0.0681] elapsed time [5.81min]
# epoch [283/500] train loss [0.0678] validation loss [1.0291] elapsed time [5.82 min]
#
# epoch [284/500] iter [000/016] loss [0.0646] elapsed time [5.83min]
# epoch [284/500] train loss [0.0677] validation loss [1.0289] elapsed time [5.85 min]
#
# epoch [285/500] iter [000/016] loss [0.0677] elapsed time [5.85min]
# epoch [285/500] train loss [0.0670] validation loss [1.0510] elapsed time [5.87 min]
#
# epoch [286/500] iter [000/016] loss [0.0654] elapsed time [5.87min]
# epoch [286/500] train loss [0.0674] validation loss [1.0305] elapsed time [5.89 min]
#
# epoch [287/500] iter [000/016] loss [0.0666] elapsed time [5.89min]
# epoch [287/500] train loss [0.0676] validation loss [1.0662] elapsed time [5.91 min]
#
# epoch [288/500] iter [000/016] loss [0.0758] elapsed time [5.91min]
# epoch [288/500] train loss [0.0678] validation loss [1.0598] elapsed time [5.93 min]
#
# epoch [289/500] iter [000/016] loss [0.0686] elapsed time [5.93min]
# epoch [289/500] train loss [0.0676] validation loss [1.0479] elapsed time [5.95 min]
#
# epoch [290/500] iter [000/016] loss [0.0680] elapsed time [5.95min]
# epoch [290/500] train loss [0.0675] validation loss [1.0293] elapsed time [5.97 min]
#
# epoch [291/500] iter [000/016] loss [0.0689] elapsed time [5.97min]
# epoch [291/500] train loss [0.0671] validation loss [1.0505] elapsed time [5.99 min]
#
# epoch [292/500] iter [000/016] loss [0.0669] elapsed time [5.99min]
# epoch [292/500] train loss [0.0672] validation loss [1.0225] elapsed time [6.01 min]
#
# epoch [293/500] iter [000/016] loss [0.0665] elapsed time [6.01min]
# epoch [293/500] train loss [0.0676] validation loss [1.0204] elapsed time [6.03 min]
#
# epoch [294/500] iter [000/016] loss [0.0655] elapsed time [6.03min]
# epoch [294/500] train loss [0.0669] validation loss [1.0494] elapsed time [6.05 min]
#
# epoch [295/500] iter [000/016] loss [0.0696] elapsed time [6.05min]
# epoch [295/500] train loss [0.0667] validation loss [1.0215] elapsed time [6.07 min]
#
# epoch [296/500] iter [000/016] loss [0.0659] elapsed time [6.07min]
# epoch [296/500] train loss [0.0673] validation loss [1.0250] elapsed time [6.09 min]
#
# epoch [297/500] iter [000/016] loss [0.0662] elapsed time [6.09min]
# epoch [297/500] train loss [0.0667] validation loss [1.0309] elapsed time [6.11 min]
#
# epoch [298/500] iter [000/016] loss [0.0645] elapsed time [6.12min]
# epoch [298/500] train loss [0.0667] validation loss [1.0221] elapsed time [6.13 min]
#
# epoch [299/500] iter [000/016] loss [0.0658] elapsed time [6.14min]
# epoch [299/500] train loss [0.0672] validation loss [1.0352] elapsed time [6.15 min]
#
# epoch [300/500] iter [000/016] loss [0.0677] elapsed time [6.16min]
# epoch [300/500] train loss [0.0674] validation loss [1.0254] elapsed time [6.17 min]
#
# epoch [301/500] iter [000/016] loss [0.0667] elapsed time [6.18min]
# epoch [301/500] train loss [0.0671] validation loss [1.0570] elapsed time [6.19 min]
#
# epoch [302/500] iter [000/016] loss [0.0704] elapsed time [6.20min]
# epoch [302/500] train loss [0.0670] validation loss [1.0168] elapsed time [6.22 min]
#
# epoch [303/500] iter [000/016] loss [0.0682] elapsed time [6.22min]
# epoch [303/500] train loss [0.0672] validation loss [1.0339] elapsed time [6.24 min]
#
# epoch [304/500] iter [000/016] loss [0.0684] elapsed time [6.24min]
# epoch [304/500] train loss [0.0683] validation loss [1.0370] elapsed time [6.26 min]
#
# epoch [305/500] iter [000/016] loss [0.0667] elapsed time [6.26min]
# epoch [305/500] train loss [0.0669] validation loss [1.0485] elapsed time [6.28 min]
#
# epoch [306/500] iter [000/016] loss [0.0682] elapsed time [6.28min]
# epoch [306/500] train loss [0.0676] validation loss [1.0593] elapsed time [6.30 min]
#
# epoch [307/500] iter [000/016] loss [0.0665] elapsed time [6.30min]
# epoch [307/500] train loss [0.0665] validation loss [1.0294] elapsed time [6.32 min]
#
# epoch [308/500] iter [000/016] loss [0.0624] elapsed time [6.32min]
# epoch [308/500] train loss [0.0662] validation loss [1.0495] elapsed time [6.34 min]
#
# epoch [309/500] iter [000/016] loss [0.0665] elapsed time [6.34min]
# epoch [309/500] train loss [0.0675] validation loss [1.0304] elapsed time [6.36 min]
#
# epoch [310/500] iter [000/016] loss [0.0711] elapsed time [6.37min]
# epoch [310/500] train loss [0.0663] validation loss [1.0212] elapsed time [6.38 min]
#
# epoch [311/500] iter [000/016] loss [0.0705] elapsed time [6.39min]
# epoch [311/500] train loss [0.0662] validation loss [1.0485] elapsed time [6.40 min]
#
# epoch [312/500] iter [000/016] loss [0.0694] elapsed time [6.41min]
# epoch [312/500] train loss [0.0661] validation loss [1.0378] elapsed time [6.42 min]
#
# ...
# epoch [396/500] train loss [0.0622] validation loss [1.0174] elapsed time [8.17 min]
#
# epoch [397/500] iter [000/016] loss [0.0642] elapsed time [8.17min]
# epoch [397/500] train loss [0.0621] validation loss [1.0133] elapsed time [8.19 min]
#
# epoch [398/500] iter [000/016] loss [0.0631] elapsed time [8.19min]
# epoch [398/500] train loss [0.0613] validation loss [1.0245] elapsed time [8.21 min]
#
# epoch [399/500] iter [000/016] loss [0.0641] elapsed time [8.21min]
# epoch [399/500] train loss [0.0619] validation loss [1.0254] elapsed time [8.23 min]
#
# epoch [400/500] iter [000/016] loss [0.0604] elapsed time [8.24min]
# epoch [400/500] train loss [0.0618] validation loss [0.9959] elapsed time [8.25 min]
#
# epoch [401/500] iter [000/016] loss [0.0649] elapsed time [8.26min]
# epoch [401/500] train loss [0.0615] validation loss [1.0078] elapsed time [8.27 min]
#
# epoch [402/500] iter [000/016] loss [0.0618] elapsed time [8.28min]
# epoch [402/500] train loss [0.0615] validation loss [1.0235] elapsed time [8.29 min]
#
# epoch [403/500] iter [000/016] loss [0.0645] elapsed time [8.30min]
# epoch [403/500] train loss [0.0616] validation loss [1.0077] elapsed time [8.31 min]
#
# epoch [404/500] iter [000/016] loss [0.0620] elapsed time [8.32min]
# epoch [404/500] train loss [0.0613] validation loss [0.9984] elapsed time [8.34 min]
#
# epoch [405/500] iter [000/016] loss [0.0648] elapsed time [8.34min]
# epoch [405/500] train loss [0.0617] validation loss [0.9991] elapsed time [8.36 min]
#
# epoch [406/500] iter [000/016] loss [0.0620] elapsed time [8.36min]
# epoch [406/500] train loss [0.0613] validation loss [1.0173] elapsed time [8.38 min]
#
# epoch [407/500] iter [000/016] loss [0.0607] elapsed time [8.38min]
# epoch [407/500] train loss [0.0610] validation loss [1.0052] elapsed time [8.40 min]
#
# epoch [408/500] iter [000/016] loss [0.0620] elapsed time [8.40min]
# epoch [408/500] train loss [0.0616] validation loss [1.0065] elapsed time [8.42 min]
#
# epoch [409/500] iter [000/016] loss [0.0627] elapsed time [8.42min]
# epoch [409/500] train loss [0.0618] validation loss [1.0152] elapsed time [8.44 min]
#
# epoch [410/500] iter [000/016] loss [0.0616] elapsed time [8.45min]
# epoch [410/500] train loss [0.0619] validation loss [1.0107] elapsed time [8.46 min]
#
# epoch [411/500] iter [000/016] loss [0.0632] elapsed time [8.47min]
# epoch [411/500] train loss [0.0621] validation loss [1.0133] elapsed time [8.48 min]
#
# epoch [412/500] iter [000/016] loss [0.0601] elapsed time [8.49min]
# epoch [412/500] train loss [0.0612] validation loss [0.9950] elapsed time [8.50 min]
#
# epoch [413/500] iter [000/016] loss [0.0617] elapsed time [8.51min]
# epoch [413/500] train loss [0.0614] validation loss [0.9982] elapsed time [8.53 min]
#
# epoch [414/500] iter [000/016] loss [0.0587] elapsed time [8.53min]
# epoch [414/500] train loss [0.0607] validation loss [0.9975] elapsed time [8.55 min]
#
# epoch [415/500] iter [000/016] loss [0.0607] elapsed time [8.55min]
# epoch [415/500] train loss [0.0611] validation loss [1.0050] elapsed time [8.57 min]
#
# epoch [416/500] iter [000/016] loss [0.0637] elapsed time [8.57min]
# epoch [416/500] train loss [0.0614] validation loss [1.0068] elapsed time [8.59 min]
#
# epoch [417/500] iter [000/016] loss [0.0581] elapsed time [8.59min]
# epoch [417/500] train loss [0.0610] validation loss [1.0102] elapsed time [8.61 min]
#
# epoch [418/500] iter [000/016] loss [0.0620] elapsed time [8.61min]
# epoch [418/500] train loss [0.0609] validation loss [1.0088] elapsed time [8.63 min]
#
# epoch [419/500] iter [000/016] loss [0.0614] elapsed time [8.64min]
# epoch [419/500] train loss [0.0613] validation loss [1.0125] elapsed time [8.65 min]
#
# epoch [420/500] iter [000/016] loss [0.0627] elapsed time [8.66min]
# epoch [420/500] train loss [0.0611] validation loss [1.0059] elapsed time [8.67 min]
#
# epoch [421/500] iter [000/016] loss [0.0597] elapsed time [8.68min]
# epoch [421/500] train loss [0.0609] validation loss [0.9968] elapsed time [8.69 min]
#
# epoch [422/500] iter [000/016] loss [0.0615] elapsed time [8.70min]
# epoch [422/500] train loss [0.0605] validation loss [0.9875] elapsed time [8.72 min]
#
# epoch [423/500] iter [000/016] loss [0.0633] elapsed time [8.72min]
# epoch [423/500] train loss [0.0606] validation loss [1.0306] elapsed time [8.74 min]
#
# epoch [424/500] iter [000/016] loss [0.0611] elapsed time [8.74min]
# epoch [424/500] train loss [0.0605] validation loss [1.0039] elapsed time [8.76 min]
#
# epoch [425/500] iter [000/016] loss [0.0629] elapsed time [8.76min]
# epoch [425/500] train loss [0.0609] validation loss [0.9992] elapsed time [8.78 min]
#
# epoch [426/500] iter [000/016] loss [0.0618] elapsed time [8.78min]
# epoch [426/500] train loss [0.0601] validation loss [1.0032] elapsed time [8.80 min]
#
# epoch [427/500] iter [000/016] loss [0.0592] elapsed time [8.80min]
# epoch [427/500] train loss [0.0598] validation loss [0.9954] elapsed time [8.82 min]
#
# epoch [428/500] iter [000/016] loss [0.0582] elapsed time [8.83min]
# epoch [428/500] train loss [0.0602] validation loss [1.0177] elapsed time [8.84 min]
#
# epoch [429/500] iter [000/016] loss [0.0593] elapsed time [8.85min]
# epoch [429/500] train loss [0.0615] validation loss [1.0016] elapsed time [8.86 min]
#
# epoch [430/500] iter [000/016] loss [0.0626] elapsed time [8.87min]
# epoch [430/500] train loss [0.0608] validation loss [0.9851] elapsed time [8.88 min]
#
# epoch [431/500] iter [000/016] loss [0.0611] elapsed time [8.89min]
# epoch [431/500] train loss [0.0599] validation loss [0.9972] elapsed time [8.90 min]
#
# epoch [432/500] iter [000/016] loss [0.0564] elapsed time [8.91min]
# epoch [432/500] train loss [0.0602] validation loss [1.0111] elapsed time [8.93 min]
#
# epoch [433/500] iter [000/016] loss [0.0559] elapsed time [8.93min]
# epoch [433/500] train loss [0.0604] validation loss [0.9973] elapsed time [8.95 min]
#
# epoch [434/500] iter [000/016] loss [0.0618] elapsed time [8.95min]
# epoch [434/500] train loss [0.0597] validation loss [1.0048] elapsed time [8.97 min]
#
# epoch [435/500] iter [000/016] loss [0.0574] elapsed time [8.97min]
# epoch [435/500] train loss [0.0602] validation loss [1.0095] elapsed time [8.99 min]
#
# epoch [436/500] iter [000/016] loss [0.0586] elapsed time [8.99min]
# epoch [436/500] train loss [0.0602] validation loss [1.0019] elapsed time [9.01 min]
#
# epoch [437/500] iter [000/016] loss [0.0593] elapsed time [9.01min]
# epoch [437/500] train loss [0.0600] validation loss [1.0178] elapsed time [9.03 min]
#
# epoch [438/500] iter [000/016] loss [0.0592] elapsed time [9.03min]
# epoch [438/500] train loss [0.0601] validation loss [0.9726] elapsed time [9.05 min]
#
# epoch [439/500] iter [000/016] loss [0.0601] elapsed time [9.06min]
# epoch [439/500] train loss [0.0601] validation loss [1.0110] elapsed time [9.07 min]
#
# epoch [440/500] iter [000/016] loss [0.0589] elapsed time [9.08min]
# epoch [440/500] train loss [0.0596] validation loss [0.9938] elapsed time [9.09 min]
#
# epoch [441/500] iter [000/016] loss [0.0567] elapsed time [9.10min]
# epoch [441/500] train loss [0.0593] validation loss [1.0153] elapsed time [9.11 min]
#
# epoch [442/500] iter [000/016] loss [0.0595] elapsed time [9.12min]
# epoch [442/500] train loss [0.0601] validation loss [1.0073] elapsed time [9.14 min]
#
# epoch [443/500] iter [000/016] loss [0.0583] elapsed time [9.14min]
# epoch [443/500] train loss [0.0594] validation loss [1.0072] elapsed time [9.16 min]
#
# epoch [444/500] iter [000/016] loss [0.0560] elapsed time [9.16min]
# epoch [444/500] train loss [0.0597] validation loss [1.0230] elapsed time [9.18 min]
#
# epoch [445/500] iter [000/016] loss [0.0585] elapsed time [9.18min]
# epoch [445/500] train loss [0.0604] validation loss [0.9983] elapsed time [9.20 min]
#
# epoch [446/500] iter [000/016] loss [0.0571] elapsed time [9.20min]
# epoch [446/500] train loss [0.0606] validation loss [0.9977] elapsed time [9.22 min]
#
# epoch [447/500] iter [000/016] loss [0.0600] elapsed time [9.22min]
# epoch [447/500] train loss [0.0600] validation loss [0.9997] elapsed time [9.24 min]
#
# epoch [448/500] iter [000/016] loss [0.0558] elapsed time [9.24min]
# epoch [448/500] train loss [0.0592] validation loss [1.0020] elapsed time [9.26 min]
#
# epoch [449/500] iter [000/016] loss [0.0592] elapsed time [9.26min]
# epoch [449/500] train loss [0.0591] validation loss [0.9869] elapsed time [9.28 min]
#
# epoch [450/500] iter [000/016] loss [0.0588] elapsed time [9.29min]
# epoch [450/500] train loss [0.0594] validation loss [1.0008] elapsed time [9.30 min]
#
# epoch [451/500] iter [000/016] loss [0.0622] elapsed time [9.31min]
# epoch [451/500] train loss [0.0595] validation loss [1.0027] elapsed time [9.32 min]
#
# epoch [452/500] iter [000/016] loss [0.0572] elapsed time [9.33min]
# epoch [452/500] train loss [0.0589] validation loss [0.9909] elapsed time [9.34 min]
#
# epoch [453/500] iter [000/016] loss [0.0593] elapsed time [9.35min]
# epoch [453/500] train loss [0.0587] validation loss [0.9968] elapsed time [9.37 min]
#
# epoch [454/500] iter [000/016] loss [0.0591] elapsed time [9.37min]
# epoch [454/500] train loss [0.0592] validation loss [1.0093] elapsed time [9.39 min]
#
# epoch [455/500] iter [000/016] loss [0.0606] elapsed time [9.39min]
# epoch [455/500] train loss [0.0601] validation loss [1.0010] elapsed time [9.41 min]
#
# epoch [456/500] iter [000/016] loss [0.0602] elapsed time [9.41min]
# epoch [456/500] train loss [0.0590] validation loss [1.0026] elapsed time [9.43 min]
#
# epoch [457/500] iter [000/016] loss [0.0625] elapsed time [9.43min]
# epoch [457/500] train loss [0.0591] validation loss [0.9776] elapsed time [9.45 min]
#
# epoch [458/500] iter [000/016] loss [0.0576] elapsed time [9.45min]
# epoch [458/500] train loss [0.0594] validation loss [0.9942] elapsed time [9.47 min]
#
# epoch [459/500] iter [000/016] loss [0.0589] elapsed time [9.47min]
# epoch [459/500] train loss [0.0588] validation loss [0.9985] elapsed time [9.49 min]
#
# epoch [460/500] iter [000/016] loss [0.0580] elapsed time [9.50min]
# epoch [460/500] train loss [0.0588] validation loss [1.0140] elapsed time [9.51 min]
#
# epoch [461/500] iter [000/016] loss [0.0578] elapsed time [9.52min]
# epoch [461/500] train loss [0.0587] validation loss [1.0047] elapsed time [9.53 min]
#
# epoch [462/500] iter [000/016] loss [0.0586] elapsed time [9.54min]
# epoch [462/500] train loss [0.0588] validation loss [1.0138] elapsed time [9.55 min]
#
# epoch [463/500] iter [000/016] loss [0.0573] elapsed time [9.56min]
# epoch [463/500] train loss [0.0587] validation loss [0.9891] elapsed time [9.58 min]
#
# epoch [464/500] iter [000/016] loss [0.0573] elapsed time [9.58min]
# epoch [464/500] train loss [0.0590] validation loss [1.0137] elapsed time [9.60 min]
#
# epoch [465/500] iter [000/016] loss [0.0569] elapsed time [9.60min]
# epoch [465/500] train loss [0.0587] validation loss [1.0093] elapsed time [9.62 min]
#
# epoch [466/500] iter [000/016] loss [0.0574] elapsed time [9.62min]
# epoch [466/500] train loss [0.0587] validation loss [1.0057] elapsed time [9.64 min]
#
# epoch [467/500] iter [000/016] loss [0.0577] elapsed time [9.64min]
# epoch [467/500] train loss [0.0585] validation loss [0.9885] elapsed time [9.66 min]
#
# epoch [468/500] iter [000/016] loss [0.0589] elapsed time [9.66min]
# epoch [468/500] train loss [0.0581] validation loss [0.9988] elapsed time [9.68 min]
#
# epoch [469/500] iter [000/016] loss [0.0581] elapsed time [9.69min]
# epoch [469/500] train loss [0.0584] validation loss [1.0178] elapsed time [9.70 min]
#
# epoch [470/500] iter [000/016] loss [0.0593] elapsed time [9.71min]
# epoch [470/500] train loss [0.0588] validation loss [1.0173] elapsed time [9.72 min]
#
# epoch [471/500] iter [000/016] loss [0.0586] elapsed time [9.73min]
# epoch [471/500] train loss [0.0584] validation loss [0.9998] elapsed time [9.74 min]
#
# epoch [472/500] iter [000/016] loss [0.0561] elapsed time [9.75min]
# epoch [472/500] train loss [0.0580] validation loss [1.0035] elapsed time [9.77 min]
#
# epoch [473/500] iter [000/016] loss [0.0596] elapsed time [9.77min]
# epoch [473/500] train loss [0.0581] validation loss [1.0194] elapsed time [9.79 min]
#
# epoch [474/500] iter [000/016] loss [0.0571] elapsed time [9.79min]
# epoch [474/500] train loss [0.0584] validation loss [1.0059] elapsed time [9.81 min]
#
# epoch [475/500] iter [000/016] loss [0.0551] elapsed time [9.81min]
# epoch [475/500] train loss [0.0582] validation loss [1.0053] elapsed time [9.83 min]
#
# epoch [476/500] iter [000/016] loss [0.0551] elapsed time [9.83min]
# epoch [476/500] train loss [0.0581] validation loss [1.0090] elapsed time [9.85 min]
#
# epoch [477/500] iter [000/016] loss [0.0561] elapsed time [9.86min]
# epoch [477/500] train loss [0.0586] validation loss [1.0006] elapsed time [9.87 min]
#
# epoch [478/500] iter [000/016] loss [0.0618] elapsed time [9.88min]
# epoch [478/500] train loss [0.0582] validation loss [1.0101] elapsed time [9.89 min]
#
# epoch [479/500] iter [000/016] loss [0.0579] elapsed time [9.90min]
# epoch [479/500] train loss [0.0586] validation loss [0.9885] elapsed time [9.91 min]
#
# epoch [480/500] iter [000/016] loss [0.0603] elapsed time [9.92min]
# epoch [480/500] train loss [0.0588] validation loss [1.0173] elapsed time [9.93 min]
#
# epoch [481/500] iter [000/016] loss [0.0596] elapsed time [9.94min]
# epoch [481/500] train loss [0.0576] validation loss [0.9996] elapsed time [9.96 min]
#
# epoch [482/500] iter [000/016] loss [0.0568] elapsed time [9.96min]
# epoch [482/500] train loss [0.0575] validation loss [0.9942] elapsed time [9.98 min]
#
# epoch [483/500] iter [000/016] loss [0.0543] elapsed time [9.98min]
# epoch [483/500] train loss [0.0579] validation loss [1.0238] elapsed time [10.00 min]
#
# epoch [484/500] iter [000/016] loss [0.0547] elapsed time [10.00min]
# epoch [484/500] train loss [0.0578] validation loss [0.9897] elapsed time [10.02 min]
#
# epoch [485/500] iter [000/016] loss [0.0595] elapsed time [10.02min]
# epoch [485/500] train loss [0.0575] validation loss [0.9894] elapsed time [10.04 min]
#
# epoch [486/500] iter [000/016] loss [0.0602] elapsed time [10.04min]
# epoch [486/500] train loss [0.0576] validation loss [0.9929] elapsed time [10.06 min]
#
# epoch [487/500] iter [000/016] loss [0.0579] elapsed time [10.06min]
# epoch [487/500] train loss [0.0575] validation loss [0.9880] elapsed time [10.08 min]
#
# epoch [488/500] iter [000/016] loss [0.0542] elapsed time [10.08min]
# epoch [488/500] train loss [0.0570] validation loss [0.9998] elapsed time [10.10 min]
#
# epoch [489/500] iter [000/016] loss [0.0563] elapsed time [10.11min]
# epoch [489/500] train loss [0.0575] validation loss [1.0016] elapsed time [10.12 min]
#
# epoch [490/500] iter [000/016] loss [0.0550] elapsed time [10.13min]
# epoch [490/500] train loss [0.0571] validation loss [1.0064] elapsed time [10.14 min]
#
# epoch [491/500] iter [000/016] loss [0.0601] elapsed time [10.15min]
# epoch [491/500] train loss [0.0574] validation loss [1.0100] elapsed time [10.16 min]
#
# epoch [492/500] iter [000/016] loss [0.0555] elapsed time [10.17min]
# epoch [492/500] train loss [0.0569] validation loss [1.0038] elapsed time [10.19 min]
#
# epoch [493/500] iter [000/016] loss [0.0578] elapsed time [10.19min]
# epoch [493/500] train loss [0.0570] validation loss [0.9899] elapsed time [10.21 min]
#
# epoch [494/500] iter [000/016] loss [0.0610] elapsed time [10.21min]
# epoch [494/500] train loss [0.0570] validation loss [0.9858] elapsed time [10.23 min]
#
# epoch [495/500] iter [000/016] loss [0.0600] elapsed time [10.23min]
# epoch [495/500] train loss [0.0577] validation loss [0.9920] elapsed time [10.25 min]
#
# epoch [496/500] iter [000/016] loss [0.0605] elapsed time [10.25min]
# epoch [496/500] train loss [0.0582] validation loss [1.0159] elapsed time [10.27 min]
#
# epoch [497/500] iter [000/016] loss [0.0568] elapsed time [10.27min]
# epoch [497/500] train loss [0.0570] validation loss [0.9976] elapsed time [10.29 min]
#
# epoch [498/500] iter [000/016] loss [0.0543] elapsed time [10.30min]
# epoch [498/500] train loss [0.0566] validation loss [1.0012] elapsed time [10.31 min]
#
# epoch [499/500] iter [000/016] loss [0.0564] elapsed time [10.32min]
# epoch [499/500] train loss [0.0565] validation loss [0.9981] elapsed time [10.33 min]

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping 
plt.legend()
plt.show()

# %%
best_epoch
# Out:
# 381

# %%
model.load_state_dict(best_model_state_dict)
# Out:
# <All keys matched successfully>

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %%
# test 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)# We can simply call pairplot on our DataFrame for an automatic visual analysis

# %%
def MAE(x,y):
  return np.mean(np.abs(x-y))

def RMSE(x,y):
  return np.sqrt(np.mean((x-y)**2))

def metric(real, pred, N=5):
  pred = pred[:, N, :]
  real =real.iloc[N:]
  real = real.iloc[:len(pred)]

  pred = np.array(pred)
  real = np.array(real)

  mae = MAE(pred, real)
  rmse = RMSE(pred, real)

  return mae, rmse

# %%
mae, rmse = metric(test_real, train_dataset.scaler.unscale(predictions), N=5)

print("MAE: {:3f}". format(mae))
print("RMSE: {:3f}". format(rmse))

#목표 기준 : N=5, mae=150, rmse=250
# Out:
# MAE: 95.759341
# RMSE: 145.585296
